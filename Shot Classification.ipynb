# %%
import mediapipe as mp # Import mediapipe
import cv2 # Import opencv
mp_drawing = mp.solutions.drawing_utils # Drawing helpers
mp_holistic = mp.solutions.holistic # Mediapipe Solution

# %%
cap = cv2.VideoCapture("C:\\Users\\Lohith\\Desktop\\Captsone Review 2\\Shots\Shots\\Sweep\\7.mp4")
# Initiate holistic model
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    
    while cap.isOpened():
        ret, frame = cap.read()
        
        # Recolor Feed
        try:
            image = cv2.cvtColor(frame[100:500,:], cv2.COLOR_BGR2RGB)
        except:
            break
        image.flags.writeable = False        
        
        # Make Detections
        results = holistic.process(image)
        # print(results.face_landmarks)
        
        # face_landmarks, pose_landmarks, left_hand_landmarks, right_hand_landmarks
        
        # Recolor image back to BGR for rendering
        image.flags.writeable = True   
        image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
        
        # 1. Draw face landmarks
        mp_drawing.draw_landmarks(image, results.face_landmarks, mp_holistic.FACEMESH_TESSELATION, 
                                 mp_drawing.DrawingSpec(color=(80,110,10), thickness=1, circle_radius=1),
                                 mp_drawing.DrawingSpec(color=(80,256,121), thickness=1, circle_radius=1)
                                 )
        
        # 2. Right hand
        mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                                 mp_drawing.DrawingSpec(color=(80,22,10), thickness=2, circle_radius=4),
                                 mp_drawing.DrawingSpec(color=(80,44,121), thickness=2, circle_radius=2)
                                 )

        # 3. Left Hand
        mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                                 mp_drawing.DrawingSpec(color=(121,22,76), thickness=2, circle_radius=4),
                                 mp_drawing.DrawingSpec(color=(121,44,250), thickness=2, circle_radius=2)
                                 )

        # 4. Pose Detections
        mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS, 
                                 mp_drawing.DrawingSpec(color=(245,117,66), thickness=2, circle_radius=4),
                                 mp_drawing.DrawingSpec(color=(245,66,230), thickness=2, circle_radius=2)
                                 )
                        
        cv2.imshow('Raw Webcam Feed', image)

        if cv2.waitKey(10) & 0xFF == ord('q'):
            break

cap.release()
cv2.destroyAllWindows()

# %%
results.pose_landmarks
# Out:
# landmark {
#   x: 0.5305318832397461
#   y: 0.19745713472366333
#   z: -0.07086841762065887
#   visibility: 0.9909238219261169
# }
# landmark {
#   x: 0.53365558385849
#   y: 0.17723947763442993
#   z: -0.06037120148539543
#   visibility: 0.9906182289123535
# }
# landmark {
#   x: 0.535791277885437
#   y: 0.1772965043783188
#   z: -0.06042088195681572
#   visibility: 0.9895513653755188
# }
# landmark {
#   x: 0.5379343628883362
#   y: 0.17708854377269745
#   z: -0.06049041822552681
#   visibility: 0.9902752637863159
# }
# landmark {
#   x: 0.5269100069999695
#   y: 0.17390604317188263
#   z: -0.0719509869813919
#   visibility: 0.9868678450584412
# }
# landmark {
#   x: 0.5244525671005249
#   y: 0.17164093255996704
#   z: -0.07195308059453964
#   visibility: 0.9845902323722839
# }
# landmark {
#   x: 0.5221501588821411
#   y: 0.1692083328962326
#   z: -0.07205204665660858
#   visibility: 0.9833804368972778
# }
# landmark {
#   x: 0.5385289788246155
#   y: 0.17507381737232208
#   z: 0.02015840634703636
#   visibility: 0.9938847422599792
# }
# landmark {
#   x: 0.516617476940155
#   y: 0.16305391490459442
#   z: -0.028076156973838806
#   visibility: 0.9915643334388733
# }
# landmark {
#   x: 0.5336621403694153
#   y: 0.2137759029865265
#   z: -0.03690686821937561
#   visibility: 0.9963139891624451
# }
# landmark {
#   x: 0.5264302492141724
#   y: 0.21017992496490479
#   z: -0.052631933242082596
#   visibility: 0.994026780128479
# }
# landmark {
#   x: 0.5446174740791321
#   y: 0.24737447500228882
#   z: 0.06761223077774048
#   visibility: 0.9990153908729553
# }
# landmark {
#   x: 0.4939114451408386
#   y: 0.22903525829315186
#   z: -0.051483698189258575
#   visibility: 0.9976734519004822
# }
# landmark {
#   x: 0.5712313652038574
#   y: 0.3764571249485016
#   z: -0.04500995948910713
#   visibility: 0.9580156803131104
# }
# landmark {
#   x: 0.489018052816391
#   y: 0.2600867748260498
#   z: -0.21580271422863007
#   visibility: 0.954486072063446
# }
# landmark {
#   x: 0.5481155514717102
#   y: 0.27591773867607117
#   z: -0.18171021342277527
#   visibility: 0.8634033203125
# }
# landmark {
#   x: 0.523050844669342
#   y: 0.19872979819774628
#   z: -0.30475282669067383
#   visibility: 0.8631051778793335
# }
# landmark {
#   x: 0.5448782444000244
#   y: 0.260780930519104
#   z: -0.20885434746742249
#   visibility: 0.7464883923530579
# }
# landmark {
#   x: 0.5314077734947205
#   y: 0.1825379878282547
#   z: -0.32902222871780396
#   visibility: 0.7986053824424744
# }
# landmark {
#   x: 0.5409166812896729
#   y: 0.24005547165870667
#   z: -0.1908121407032013
#   visibility: 0.7356159090995789
# }
# landmark {
#   x: 0.531514048576355
#   y: 0.1807347685098648
#   z: -0.318097323179245
#   visibility: 0.7868934869766235
# }
# landmark {
#   x: 0.5418793559074402
#   y: 0.2440321147441864
#   z: -0.1787644326686859
#   visibility: 0.7255175709724426
# }
# landmark {
#   x: 0.5284348130226135
#   y: 0.18971391022205353
#   z: -0.3018728494644165
#   visibility: 0.7661556601524353
# }
# landmark {
#   x: 0.5329505205154419
#   y: 0.6159211993217468
#   z: 0.02437778189778328
#   visibility: 0.9962227940559387
# }
# landmark {
#   x: 0.4982287287712097
#   y: 0.6183311939239502
#   z: -0.02414797618985176
#   visibility: 0.9941782355308533
# }
# landmark {
#   x: 0.5347431898117065
#   y: 0.8740473985671997
#   z: -0.04329914599657059
#   visibility: 0.6108901500701904
# }
# landmark {
#   x: 0.4969209134578705
#   y: 0.8685987591743469
#   z: -0.0369856134057045
#   visibility: 0.54579097032547
# }
# landmark {
#   x: 0.541225790977478
#   y: 1.1044094562530518
#   z: 0.032531995326280594
#   visibility: 0.29860424995422363
# }
# landmark {
#   x: 0.5008401870727539
#   y: 1.0955711603164673
#   z: 0.062225501984357834
#   visibility: 0.26987096667289734
# }
# landmark {
#   x: 0.5385666489601135
#   y: 1.133597731590271
#   z: 0.03609282523393631
#   visibility: 0.29338544607162476
# }
# landmark {
#   x: 0.5013618469238281
#   y: 1.1207486391067505
#   z: 0.06971796602010727
#   visibility: 0.2055942863225937
# }
# landmark {
#   x: 0.5467504858970642
#   y: 1.1787434816360474
#   z: -0.04270397871732712
#   visibility: 0.24296492338180542
# }
# landmark {
#   x: 0.5048059225082397
#   y: 1.1822006702423096
#   z: -0.018285537138581276
#   visibility: 0.21415351331233978
# }

# %%
import csv
import os
import numpy as np
num_coords = len(results.pose_landmarks.landmark)
print(num_coords)
landmarks = ['class']
for val in range(1, num_coords+1):
    landmarks += ['x{}'.format(val), 'y{}'.format(val), 'z{}'.format(val), 'v{}'.format(val)]
landmarks
with open('coords.csv', mode='w', newline='') as f:
    csv_writer = csv.writer(f, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)
    csv_writer.writerow(landmarks)
# Out:
# 33

# %%
num_coords = len(results.pose_landmarks.landmark)
print(num_coords)
# Out:
# 33

# %%
class_name = "Sweep Shot"

# %%
cap = cv2.VideoCapture("C:\\Users\\Lohith\\Desktop\\Captsone Review 2\\Shots\Shots\\Sweep\\7.mp4")
# Initiate holistic model
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    
    while cap.isOpened():
        ret, frame = cap.read()
        
        # Recolor Feed
        try:
            image = cv2.cvtColor(frame[100:500,:], cv2.COLOR_BGR2RGB)
            image=cv2.flip(image,1)
        except:
            break
        image.flags.writeable = False        
        
        # Make Detections
        results = holistic.process(image)
        # print(results.face_landmarks)
        
        # face_landmarks, pose_landmarks, left_hand_landmarks, right_hand_landmarks
        
        # Recolor image back to BGR for rendering
        image.flags.writeable = True   
        image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
        
        # 1. Draw face landmarks
        mp_drawing.draw_landmarks(image, results.face_landmarks, mp_holistic.FACEMESH_TESSELATION, 
                                 mp_drawing.DrawingSpec(color=(80,110,10), thickness=1, circle_radius=1),
                                 mp_drawing.DrawingSpec(color=(80,256,121), thickness=1, circle_radius=1)
                                 )
        
        # 2. Right hand
        mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                                 mp_drawing.DrawingSpec(color=(80,22,10), thickness=2, circle_radius=4),
                                 mp_drawing.DrawingSpec(color=(80,44,121), thickness=2, circle_radius=2)
                                 )

        # 3. Left Hand
        mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                                 mp_drawing.DrawingSpec(color=(121,22,76), thickness=2, circle_radius=4),
                                 mp_drawing.DrawingSpec(color=(121,44,250), thickness=2, circle_radius=2)
                                 )

        # 4. Pose Detections
        mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS, 
                                 mp_drawing.DrawingSpec(color=(245,117,66), thickness=2, circle_radius=4),
                                 mp_drawing.DrawingSpec(color=(245,66,230), thickness=2, circle_radius=2)
                                 )
        # Export coordinates
        try:
            # Extract Pose landmarks
            pose = results.pose_landmarks.landmark
            pose_row = list(np.array([[landmark.x, landmark.y, landmark.z, landmark.visibility] for landmark in pose]).flatten())
            
            # Extract Face landmarks
            '''face = results.face_landmarks.landmark
            face_row = list(np.array([[landmark.x, landmark.y, landmark.z, landmark.visibility] for landmark in face]).flatten())'''
            
            # Concate rows
            row = pose_row
            print(row)
            # Append class name 
            row.insert(0, class_name)
            
            # Export to CSV
            with open('coords.csv', mode='a', newline='') as f:
                csv_writer = csv.writer(f, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)
                csv_writer.writerow(row) 
                
            
        except:
            pass
                        
        cv2.imshow('Raw Webcam Feed', image)

        if cv2.waitKey(10) & 0xFF == ord('q'):
            break

cap.release()
cv2.destroyAllWindows()
# Out:
# [0.5445951819419861, 0.3678772747516632, -0.08807703107595444, 0.9989244341850281, 0.5469112396240234, 0.3542376458644867, -0.07752993702888489, 0.9986233711242676, 0.5471364855766296, 0.3555966317653656, -0.07758061587810516, 0.9984470009803772, 0.5474374294281006, 0.35687121748924255, -0.07763385027647018, 0.9981720447540283, 0.5449890494346619, 0.34824585914611816, -0.08987347036600113, 0.9990179538726807, 0.5438230633735657, 0.34597134590148926, -0.08989404886960983, 0.9991191029548645, 0.5420070886611938, 0.3430272936820984, -0.08988741785287857, 0.9991346001625061, 0.5413617491722107, 0.3591963052749634, -0.026728669181466103, 0.9962031245231628, 0.5331764817237854, 0.3454270660877228, -0.0815168023109436, 0.9988217949867249, 0.5409536361694336, 0.3837476968765259, -0.06798523664474487, 0.9929326772689819, 0.5380097031593323, 0.37804940342903137, -0.08391391485929489, 0.9962143301963806, 0.5266030430793762, 0.4086507558822632, 0.03733361139893532, 0.9972232580184937, 0.5156173706054688, 0.4044645428657532, -0.10749505460262299, 0.9993512034416199, 0.5325746536254883, 0.47717148065567017, 0.07211946696043015, 0.10158485174179077, 0.5258380174636841, 0.5005072355270386, -0.13448671996593475, 0.9836365580558777, 0.5469698309898376, 0.5086650252342224, 0.045139823108911514, 0.21058382093906403, 0.5560154914855957, 0.5095710754394531, -0.12539498507976532, 0.9063779711723328, 0.5506454110145569, 0.5214266777038574, 0.04395678639411926, 0.2371465563774109, 0.5631252527236938, 0.5166523456573486, -0.13840791583061218, 0.8694201111793518, 0.5515347719192505, 0.5108107328414917, 0.03549261763691902, 0.2503708004951477, 0.5640622973442078, 0.49885255098342896, -0.13724711537361145, 0.8688532710075378, 0.5498193502426147, 0.5088334083557129, 0.04013495519757271, 0.23963920772075653, 0.5602794289588928, 0.49793165922164917, -0.1244301050901413, 0.8179574012756348, 0.4902697503566742, 0.589799702167511, 0.0472230426967144, 0.9972284436225891, 0.47799840569496155, 0.5866324305534363, -0.04717908427119255, 0.9992557168006897, 0.5099323987960815, 0.6832905411720276, 0.08627673983573914, 0.4952435791492462, 0.5065332651138306, 0.6821736693382263, -0.09494936466217041, 0.992073118686676, 0.5012158751487732, 0.8175804615020752, 0.15004245936870575, 0.5915939211845398, 0.5051401257514954, 0.8443811535835266, -0.08506232500076294, 0.987987756729126, 0.49457359313964844, 0.8387293815612793, 0.15499067306518555, 0.5326407551765442, 0.4971366822719574, 0.876647412776947, -0.08547163754701614, 0.9629951119422913, 0.5177353024482727, 0.8484203219413757, 0.14486108720302582, 0.7002197504043579, 0.5234383940696716, 0.8869340419769287, -0.11569733917713165, 0.9851381778717041]
# [0.5448079109191895, 0.3669777810573578, -0.119170643389225, 0.9989290237426758, 0.5469120144844055, 0.3531181812286377, -0.10819170624017715, 0.9986512660980225, 0.547239363193512, 0.3546006679534912, -0.10823875665664673, 0.9984879493713379, 0.5476052165031433, 0.35540470480918884, -0.1082773432135582, 0.9982153177261353, 0.5448821187019348, 0.34810593724250793, -0.12132124602794647, 0.9990091919898987, 0.5432204008102417, 0.34575870633125305, -0.12136260420084, 0.9991125464439392, 0.5413006544113159, 0.34304869174957275, -0.12138062715530396, 0.9991251230239868, 0.541540265083313, 0.358227014541626, -0.0525369755923748, 0.9961347579956055, 0.5328537225723267, 0.3451864719390869, -0.11231853812932968, 0.9987366199493408, 0.5411677360534668, 0.38253799080848694, -0.09726060926914215, 0.9931906461715698, 0.5380061268806458, 0.37779098749160767, -0.11475630849599838, 0.996324896812439, 0.5284394025802612, 0.40877074003219604, 0.014066730625927448, 0.9973459839820862, 0.514590859413147, 0.4068727195262909, -0.1333075761795044, 0.9993693232536316, 0.5247394442558289, 0.505111813545227, 0.03977937996387482, 0.10812141001224518, 0.5253140330314636, 0.4978092908859253, -0.17036248743534088, 0.9785678386688232, 0.5304608941078186, 0.5997043251991272, 0.0037125039380043745, 0.2178831845521927, 0.5535075664520264, 0.4984147250652313, -0.172200545668602, 0.8973690271377563, 0.5315929651260376, 0.6271878480911255, 0.0002994825190398842, 0.24292287230491638, 0.5603493452072144, 0.5040454864501953, -0.18933308124542236, 0.8619011044502258, 0.5302231907844543, 0.6202350854873657, -0.010694348253309727, 0.2556299865245819, 0.5610686540603638, 0.48678919672966003, -0.18882015347480774, 0.8608731031417847, 0.5288592576980591, 0.611074686050415, -0.0021434116642922163, 0.2450062483549118, 0.557315468788147, 0.486901193857193, -0.17179323732852936, 0.8054190278053284, 0.49274787306785583, 0.5856220126152039, 0.049145933240652084, 0.9973768591880798, 0.477872371673584, 0.5864404439926147, -0.049136124551296234, 0.9993206262588501, 0.5098073482513428, 0.6679455637931824, 0.13769316673278809, 0.48741504549980164, 0.5058295130729675, 0.6960427761077881, -0.11741159856319427, 0.9922999739646912, 0.49706631898880005, 0.7946571111679077, 0.24567309021949768, 0.5925671458244324, 0.5055898427963257, 0.8542736172676086, -0.11626747995615005, 0.9886878132820129, 0.4907606244087219, 0.8160635232925415, 0.2548145353794098, 0.5305492877960205, 0.49797457456588745, 0.8842509984970093, -0.1184273213148117, 0.9640938639640808, 0.5124416351318359, 0.8319156765937805, 0.2376667708158493, 0.7020255923271179, 0.5250366926193237, 0.8931443691253662, -0.16983261704444885, 0.9859783053398132]
# [0.5452156066894531, 0.36615630984306335, -0.1166321188211441, 0.998896598815918, 0.5469722747802734, 0.3520166873931885, -0.10604113340377808, 0.9986363053321838, 0.5474460124969482, 0.35360461473464966, -0.10609040409326553, 0.9984855055809021, 0.5478441119194031, 0.3540801703929901, -0.10613123327493668, 0.9982120394706726, 0.5448886752128601, 0.34786486625671387, -0.11946926265954971, 0.9989573955535889, 0.5431339740753174, 0.3454410433769226, -0.11950919777154922, 0.9990668296813965, 0.5412763357162476, 0.3429175913333893, -0.11952771246433258, 0.9990760684013367, 0.5416950583457947, 0.3570491671562195, -0.0520593523979187, 0.9959514141082764, 0.5328563451766968, 0.3451225757598877, -0.11332549899816513, 0.9985763430595398, 0.541573166847229, 0.38159114122390747, -0.0952979251742363, 0.9933204054832458, 0.5381581783294678, 0.3771853744983673, -0.11320579051971436, 0.9963430166244507, 0.5283874273300171, 0.41402798891067505, 0.012857722118496895, 0.9974496960639954, 0.5141748189926147, 0.4081209599971771, -0.13443510234355927, 0.9993740916252136, 0.5231654047966003, 0.5101357102394104, 0.03877207264304161, 0.11313952505588531, 0.5249546766281128, 0.49629807472229004, -0.1726187765598297, 0.9726927280426025, 0.5291121006011963, 0.6059576272964478, 0.0037162743974477053, 0.22461754083633423, 0.552111029624939, 0.4947982132434845, -0.1766527146100998, 0.8878769874572754, 0.5302650928497314, 0.6336199641227722, 0.0004898852203041315, 0.2485077828168869, 0.5587457418441772, 0.5000720024108887, -0.19395484030246735, 0.8544443249702454, 0.5289214849472046, 0.6265995502471924, -0.010445568710565567, 0.260846346616745, 0.5595393180847168, 0.4828413724899292, -0.19324715435504913, 0.8529515862464905, 0.5275285840034485, 0.6173930168151855, -0.0020923111587762833, 0.2502792477607727, 0.5558709502220154, 0.4830886721611023, -0.17623746395111084, 0.7932099103927612, 0.4938029646873474, 0.5835496783256531, 0.04969251528382301, 0.9975004196166992, 0.4778248369693756, 0.5862972736358643, -0.04969044029712677, 0.9993763566017151, 0.509687066078186, 0.6638749837875366, 0.1366044580936432, 0.4765290915966034, 0.5049710869789124, 0.700624406337738, -0.11631882190704346, 0.9923326373100281, 0.4965845048427582, 0.7935732007026672, 0.2413804531097412, 0.5895651578903198, 0.505859375, 0.8571733832359314, -0.11271307617425919, 0.989189624786377, 0.4903566241264343, 0.815646767616272, 0.25019779801368713, 0.5258936882019043, 0.49842125177383423, 0.8867661952972412, -0.1145816445350647, 0.9646762609481812, 0.5124138593673706, 0.8313508629798889, 0.23276448249816895, 0.7009681463241577, 0.5256962180137634, 0.8953794240951538, -0.16516034305095673, 0.9865930080413818]
# [0.545391857624054, 0.36549216508865356, -0.11778698861598969, 0.9988945126533508, 0.5470132827758789, 0.3511882722377777, -0.107174813747406, 0.9986559748649597, 0.5475684404373169, 0.35279181599617004, -0.10722202062606812, 0.9985194206237793, 0.5479922294616699, 0.3530949354171753, -0.1072617918252945, 0.9982507824897766, 0.5448904037475586, 0.3475764989852905, -0.12052343785762787, 0.998937726020813, 0.5430788397789001, 0.3451114892959595, -0.12056386470794678, 0.9990518689155579, 0.5412585735321045, 0.3427373170852661, -0.1205829605460167, 0.9990552067756653, 0.5417894124984741, 0.35615721344947815, -0.05312567949295044, 0.9959399104118347, 0.5328004360198975, 0.34485816955566406, -0.11411575973033905, 0.9984908699989319, 0.5417670607566833, 0.3808407485485077, -0.09642913937568665, 0.9935791492462158, 0.538182258605957, 0.3769967555999756, -0.11428651958703995, 0.9964413046836853, 0.5285963416099548, 0.41372355818748474, 0.011399798095226288, 0.9975655674934387, 0.5139118432998657, 0.40869998931884766, -0.13580378890037537, 0.9993836879730225, 0.5227606892585754, 0.5112907290458679, 0.03603285178542137, 0.11868128925561905, 0.5247902870178223, 0.49550896883010864, -0.17946895956993103, 0.9674525260925293, 0.5274910926818848, 0.6190172433853149, 0.0014111518394201994, 0.2324463576078415, 0.5515859723091125, 0.49503958225250244, -0.18952077627182007, 0.8804394602775574, 0.5287759304046631, 0.647965669631958, -0.0015166655648499727, 0.2552949786186218, 0.5582403540611267, 0.500473141670227, -0.20770688354969025, 0.848953366279602, 0.5273371934890747, 0.6424862742424011, -0.0128320949152112, 0.26734691858291626, 0.559137225151062, 0.48339149355888367, -0.20625726878643036, 0.8470094203948975, 0.5257816314697266, 0.6325554847717285, -0.004513368010520935, 0.2567797303199768, 0.5554554462432861, 0.48363885283470154, -0.18901929259300232, 0.7834619879722595, 0.49400457739830017, 0.5828975439071655, 0.04999445378780365, 0.9976449608802795, 0.4777967035770416, 0.5862500071525574, -0.04999909922480583, 0.9994281530380249, 0.5096253156661987, 0.6631750464439392, 0.1339513212442398, 0.4695703387260437, 0.5046006441116333, 0.7030652761459351, -0.11216878890991211, 0.9923913478851318, 0.49642258882522583, 0.795167863368988, 0.23873452842235565, 0.5899280309677124, 0.5060939192771912, 0.8573625087738037, -0.10530849546194077, 0.9896763563156128, 0.4902368485927582, 0.8174041509628296, 0.2475525140762329, 0.5235292911529541, 0.49882563948631287, 0.8873653411865234, -0.10673992335796356, 0.9651561379432678, 0.5124810934066772, 0.8325093984603882, 0.22966888546943665, 0.7025536894798279, 0.5260787606239319, 0.8961392045021057, -0.15570729970932007, 0.9871934056282043]
# [0.5440528988838196, 0.3707250654697418, -0.10796865075826645, 0.9989088773727417, 0.5460458397865295, 0.3584371507167816, -0.09411288052797318, 0.9987444877624512, 0.5469613075256348, 0.3608354330062866, -0.09420348703861237, 0.9986141920089722, 0.5476983785629272, 0.36205199360847473, -0.0942637026309967, 0.9983790516853333, 0.542752742767334, 0.35189953446388245, -0.10230976343154907, 0.998977541923523, 0.5409338474273682, 0.3491879403591156, -0.10232965648174286, 0.9990782141685486, 0.5388005375862122, 0.3459901809692383, -0.10235802084207535, 0.9990914463996887, 0.5427583456039429, 0.36482948064804077, -0.03271880000829697, 0.9962777495384216, 0.5313788056373596, 0.34810540080070496, -0.07457786053419113, 0.9986051321029663, 0.5416713953018188, 0.38662898540496826, -0.08384500443935394, 0.9941756725311279, 0.5374953746795654, 0.3797891139984131, -0.09468692541122437, 0.996766209602356, 0.5351330041885376, 0.44749999046325684, 0.01395068783313036, 0.997706413269043, 0.506766676902771, 0.4086102247238159, -0.09978000074625015, 0.9993653893470764, 0.5449017882347107, 0.5350474715232849, -0.017558753490447998, 0.1492319405078888, 0.5122767686843872, 0.5034038424491882, -0.1721777617931366, 0.9690425992012024, 0.5666219592094421, 0.5716968774795532, -0.09848339855670929, 0.2548912465572357, 0.5487874746322632, 0.5369299054145813, -0.1672072410583496, 0.8862251043319702, 0.5723310708999634, 0.5958716869354248, -0.11218534409999847, 0.27441897988319397, 0.5577338337898254, 0.5523653626441956, -0.1837119311094284, 0.8522268533706665, 0.5724255442619324, 0.584506094455719, -0.11909280717372894, 0.2857130169868469, 0.5592538118362427, 0.5328627228736877, -0.1797587126493454, 0.8495013117790222, 0.5684084892272949, 0.5897837281227112, -0.1045391783118248, 0.27665334939956665, 0.5553809404373169, 0.5312037467956543, -0.16545741260051727, 0.7870845198631287, 0.5007658004760742, 0.6087183952331543, 0.036016110330820084, 0.99778813123703, 0.47752103209495544, 0.6042463183403015, -0.035890866070985794, 0.999360978603363, 0.5121271014213562, 0.6912695169448853, -0.06216645985841751, 0.5012671947479248, 0.499337375164032, 0.7024299502372742, -0.15110626816749573, 0.991302490234375, 0.5006894469261169, 0.8680916428565979, -0.030618425458669662, 0.6057693958282471, 0.5071995854377747, 0.8563755750656128, -0.14448611438274384, 0.9874509572982788, 0.4958723187446594, 0.8898217678070068, -0.02975277602672577, 0.5443239212036133, 0.5047489404678345, 0.8875049352645874, -0.14550624787807465, 0.9603244662284851, 0.5142115950584412, 0.903155505657196, -0.07587800920009613, 0.7142736315727234, 0.5257651805877686, 0.8984057903289795, -0.19936895370483398, 0.9852864742279053]
# [0.5440657734870911, 0.3703836500644684, -0.07595701515674591, 0.9989464282989502, 0.5461908578872681, 0.35795336961746216, -0.06315143406391144, 0.9988412261009216, 0.5472834706306458, 0.36032187938690186, -0.06323473155498505, 0.9987189769744873, 0.5484368205070496, 0.3615521490573883, -0.06329108029603958, 0.998511016368866, 0.5428225994110107, 0.35169434547424316, -0.07119379937648773, 0.9990308284759521, 0.5408815741539001, 0.34892767667770386, -0.07120703160762787, 0.9991177320480347, 0.5388426184654236, 0.3457767963409424, -0.07123889029026031, 0.9991399049758911, 0.5450881719589233, 0.364668071269989, -0.002466107252985239, 0.9966065883636475, 0.531485378742218, 0.34803611040115356, -0.038478784263134, 0.9987224340438843, 0.5423786044120789, 0.38646721839904785, -0.052836399525403976, 0.9947278499603271, 0.5376177430152893, 0.3795880377292633, -0.0631348192691803, 0.9970701932907104, 0.5391496419906616, 0.45308852195739746, 0.038098178803920746, 0.9978793859481812, 0.5073938369750977, 0.40494659543037415, -0.06664297729730606, 0.9993961453437805, 0.5516642928123474, 0.5370090007781982, -0.005617548245936632, 0.17451609671115875, 0.5106184482574463, 0.4999690651893616, -0.1235613226890564, 0.9678263068199158, 0.5732656717300415, 0.5527322888374329, -0.10263087600469589, 0.2779078483581543, 0.546528697013855, 0.5435112714767456, -0.13972575962543488, 0.885286808013916, 0.5788246989250183, 0.5694723725318909, -0.11915798485279083, 0.295664519071579, 0.5554194450378418, 0.5647997856140137, -0.15543434023857117, 0.84772127866745, 0.5786159038543701, 0.5556964874267578, -0.12345905601978302, 0.30615749955177307, 0.5579412579536438, 0.5449175834655762, -0.1506579965353012, 0.8443534970283508, 0.5744171738624573, 0.5593709945678711, -0.10795583575963974, 0.2972535490989685, 0.5540992021560669, 0.5409250855445862, -0.13773953914642334, 0.7819016575813293, 0.5029920339584351, 0.611336350440979, 0.035382118076086044, 0.9979434609413147, 0.4775744378566742, 0.6060864925384521, -0.03524943068623543, 0.9993707537651062, 0.5121699571609497, 0.7097985744476318, -0.04600898176431656, 0.5199460387229919, 0.4988327920436859, 0.7025173306465149, -0.1558092087507248, 0.9901685118675232, 0.503247082233429, 0.8640608191490173, -0.013021813705563545, 0.6123008131980896, 0.5071501731872559, 0.8604580163955688, -0.15633298456668854, 0.9846512079238892, 0.49605053663253784, 0.9038951992988586, -0.012063199654221535, 0.5573582053184509, 0.5033606290817261, 0.8918460607528687, -0.15808960795402527, 0.952442467212677, 0.5157312154769897, 0.903840184211731, -0.058804839849472046, 0.718923807144165, 0.524612545967102, 0.9074707627296448, -0.21614304184913635, 0.9826019406318665]
# [0.5448119044303894, 0.36564141511917114, -0.08402938395738602, 0.9987045526504517, 0.5481076836585999, 0.3505057990550995, -0.07266483455896378, 0.9987527132034302, 0.5472429990768433, 0.3488624095916748, -0.07274569571018219, 0.9986351132392883, 0.548445999622345, 0.3509770929813385, -0.07280396670103073, 0.9984543919563293, 0.5430175065994263, 0.34588301181793213, -0.0802212506532669, 0.9987908005714417, 0.5410176515579224, 0.3419322669506073, -0.08023716509342194, 0.9988633394241333, 0.5388807058334351, 0.3376995325088501, -0.0802747830748558, 0.9989302754402161, 0.5463235974311829, 0.3553656339645386, -0.015854036435484886, 0.9966480731964111, 0.5324324369430542, 0.3404003977775574, -0.04626338928937912, 0.9986717104911804, 0.544309139251709, 0.3812348544597626, -0.06213877350091934, 0.9951266050338745, 0.5387763381004333, 0.37523314356803894, -0.07144903391599655, 0.9972928166389465, 0.5427693724632263, 0.4433270990848541, 0.026573773473501205, 0.9980297684669495, 0.5084779262542725, 0.3977293074131012, -0.06601840257644653, 0.9994301795959473, 0.5534236431121826, 0.5278798937797546, -0.024480292573571205, 0.20243139564990997, 0.5079512596130371, 0.4921078085899353, -0.10802668333053589, 0.9654897451400757, 0.5745648145675659, 0.5483231544494629, -0.1214478611946106, 0.3022777736186981, 0.5435283184051514, 0.5372986197471619, -0.13062593340873718, 0.8853493332862854, 0.5813944339752197, 0.5639264583587646, -0.13995479047298431, 0.3211238384246826, 0.5521180033683777, 0.5581055283546448, -0.14693531394004822, 0.8472381234169006, 0.5808892846107483, 0.5509297847747803, -0.145614355802536, 0.33147281408309937, 0.5554506778717041, 0.5384958386421204, -0.14512325823307037, 0.8438993096351624, 0.5762776732444763, 0.5516320466995239, -0.12718425691127777, 0.3227843940258026, 0.551877498626709, 0.5344117879867554, -0.12997955083847046, 0.7826741933822632, 0.5052071213722229, 0.6068181991577148, 0.03334743157029152, 0.9980356097221375, 0.47879356145858765, 0.6029826402664185, -0.033195093274116516, 0.9993950724601746, 0.5132138729095459, 0.706163763999939, -0.008801640942692757, 0.509258508682251, 0.4998851716518402, 0.7045364379882812, -0.15488982200622559, 0.9887128472328186, 0.5027755498886108, 0.850006103515625, 0.05472154542803764, 0.5978658199310303, 0.5063335299491882, 0.868573009967804, -0.14885708689689636, 0.9822568893432617, 0.49500393867492676, 0.8789839744567871, 0.058966152369976044, 0.553970992565155, 0.5017565488815308, 0.9013643860816956, -0.14989423751831055, 0.9471994042396545, 0.5155147314071655, 0.8964946866035461, 0.022277219220995903, 0.6998330354690552, 0.5240913033485413, 0.9186039566993713, -0.2057783603668213, 0.9797654747962952]
# [0.5449150800704956, 0.3668787479400635, -0.12462253868579865, 0.9985103011131287, 0.5481022596359253, 0.3529510796070099, -0.11280013620853424, 0.9986125826835632, 0.5479996204376221, 0.3525178134441376, -0.11288410425186157, 0.9984919428825378, 0.5496891736984253, 0.3522430658340454, -0.11295010149478912, 0.9983451962471008, 0.5431329011917114, 0.34638699889183044, -0.12140126526355743, 0.9984767436981201, 0.5411695241928101, 0.34201762080192566, -0.12141184508800507, 0.9985150694847107, 0.5390864610671997, 0.33799242973327637, -0.12144552171230316, 0.998589038848877, 0.5469241738319397, 0.35763081908226013, -0.05019143968820572, 0.9965952038764954, 0.5324375629425049, 0.3406554162502289, -0.08570457249879837, 0.9986182451248169, 0.5442559123039246, 0.3819863200187683, -0.10037656128406525, 0.99547278881073, 0.5388983488082886, 0.3756939768791199, -0.11114007234573364, 0.9974574446678162, 0.5412759780883789, 0.4467258155345917, -0.0028581987135112286, 0.9981487989425659, 0.5083171725273132, 0.3982720673084259, -0.10246111452579498, 0.9993733763694763, 0.5535933971405029, 0.5281230807304382, -0.049881450831890106, 0.2377656251192093, 0.5112013816833496, 0.49250099062919617, -0.15483100712299347, 0.9666165709495544, 0.5739355087280273, 0.5443909168243408, -0.1568412482738495, 0.3349815309047699, 0.5455620884895325, 0.5414177179336548, -0.17378860712051392, 0.88929283618927, 0.5817283391952515, 0.5624993443489075, -0.17656561732292175, 0.3525635600090027, 0.5535264015197754, 0.5629640221595764, -0.19307513535022736, 0.85003662109375, 0.5814775824546814, 0.5504162907600403, -0.18367543816566467, 0.36273038387298584, 0.5557460188865662, 0.5434955358505249, -0.1896057277917862, 0.8463165760040283, 0.5770346522331238, 0.5500795841217041, -0.16376157104969025, 0.35397574305534363, 0.5524211525917053, 0.5386642813682556, -0.1727742850780487, 0.7854820489883423, 0.5048465728759766, 0.610252320766449, 0.03362320363521576, 0.998171329498291, 0.478905588388443, 0.6048688292503357, -0.03352302685379982, 0.9993236064910889, 0.5129231810569763, 0.7164911031723022, -0.02667842246592045, 0.5320624709129333, 0.49492770433425903, 0.7194113731384277, -0.12970708310604095, 0.9870681166648865, 0.5033922791481018, 0.8721397519111633, 0.03163266181945801, 0.6140755414962769, 0.5063229203224182, 0.8496047258377075, -0.03996003419160843, 0.9712038040161133, 0.49558162689208984, 0.9036605358123779, 0.03518985956907272, 0.5665274262428284, 0.5029999017715454, 0.8757618069648743, -0.03298092633485794, 0.9260387420654297, 0.5176120400428772, 0.9156381487846375, -0.009304368868470192, 0.7073997855186462, 0.5239275693893433, 0.9124576449394226, -0.079078808426857, 0.9692436456680298]
# [0.5452925562858582, 0.36410558223724365, -0.15452346205711365, 0.9985735416412354, 0.5504366755485535, 0.34452569484710693, -0.14584919810295105, 0.9986768960952759, 0.55143141746521, 0.34580203890800476, -0.14592312276363373, 0.9985515475273132, 0.5528592467308044, 0.34618037939071655, -0.14598795771598816, 0.9984288215637207, 0.5446835160255432, 0.33342498540878296, -0.15229196846485138, 0.9985179305076599, 0.5423175692558289, 0.32797470688819885, -0.15234415233135223, 0.9985249042510986, 0.5401598811149597, 0.3228897452354431, -0.1523958444595337, 0.9986196756362915, 0.552698016166687, 0.35132870078086853, -0.0801604688167572, 0.9967968463897705, 0.5364658236503601, 0.31696969270706177, -0.10988730192184448, 0.9986445903778076, 0.5442360043525696, 0.38565579056739807, -0.1277257651090622, 0.9958877563476562, 0.5385977625846863, 0.37715598940849304, -0.13650506734848022, 0.9976865649223328, 0.5525153875350952, 0.43863096833229065, -0.018801528960466385, 0.9983183741569519, 0.5084527730941772, 0.3877338767051697, -0.09817222505807877, 0.999426007270813, 0.5525740385055542, 0.524991512298584, -0.02802075445652008, 0.2781863510608673, 0.49557265639305115, 0.4531267285346985, -0.154839426279068, 0.959385871887207, 0.5654025673866272, 0.6161930561065674, -0.1022915467619896, 0.3594781458377838, 0.5130270719528198, 0.4914156198501587, -0.2403852641582489, 0.8803526759147644, 0.571442186832428, 0.6485347747802734, -0.11571869999170303, 0.37244361639022827, 0.5157653093338013, 0.5076603889465332, -0.26246485114097595, 0.8447429537773132, 0.5718628168106079, 0.6404567956924438, -0.12844453752040863, 0.3832835853099823, 0.5202604532241821, 0.4955202043056488, -0.26600217819213867, 0.8413164615631104, 0.5683409571647644, 0.6294646263122559, -0.10920445621013641, 0.37443339824676514, 0.5194088816642761, 0.4936700165271759, -0.24324694275856018, 0.781323254108429, 0.512021005153656, 0.6076273918151855, 0.034933529794216156, 0.9983087182044983, 0.4866734445095062, 0.5961401462554932, -0.03485315293073654, 0.999376654624939, 0.521468997001648, 0.7088211178779602, -0.025646861642599106, 0.5465611219406128, 0.4980449676513672, 0.7153975963592529, -0.1703064739704132, 0.9869025945663452, 0.5042173266410828, 0.8649664521217346, 0.027823517099022865, 0.631431519985199, 0.5059046149253845, 0.9027588367462158, -0.1558811217546463, 0.9729515910148621, 0.49558502435684204, 0.8933733105659485, 0.03040659800171852, 0.5919549465179443, 0.5007511377334595, 0.9338676929473877, -0.1567949801683426, 0.9286714792251587, 0.520969808101654, 0.9202948808670044, -0.019257258623838425, 0.7206943035125732, 0.5239478349685669, 0.9594072699546814, -0.2259124219417572, 0.9707463383674622]
# [0.5453026294708252, 0.3699449598789215, -0.14297863841056824, 0.998656690120697, 0.5501416921615601, 0.3554156422615051, -0.13355401158332825, 0.9987604022026062, 0.5508919954299927, 0.35917171835899353, -0.13362668454647064, 0.9986327290534973, 0.552162230014801, 0.3616277575492859, -0.13368470966815948, 0.998525857925415, 0.544532835483551, 0.33827391266822815, -0.14146175980567932, 0.9985949397087097, 0.542076051235199, 0.3319089412689209, -0.1415034383535385, 0.9985878467559814, 0.5399105548858643, 0.3269239366054535, -0.14154666662216187, 0.9986911416053772, 0.551337718963623, 0.351753830909729, -0.06486234813928604, 0.9970393180847168, 0.5363982915878296, 0.32409846782684326, -0.10074521601200104, 0.998729407787323, 0.5441965460777283, 0.39670467376708984, -0.11465270817279816, 0.9962660074234009, 0.5384460091590881, 0.388334721326828, -0.12514768540859222, 0.9978945255279541, 0.5524563193321228, 0.4357052147388458, 0.00013633084017783403, 0.9984774589538574, 0.5080852508544922, 0.3902532160282135, -0.09419869631528854, 0.9994742274284363, 0.559264600276947, 0.5226321816444397, -0.009684162214398384, 0.2996901273727417, 0.49369603395462036, 0.4610990583896637, -0.16123980283737183, 0.9577056765556335, 0.5774046182632446, 0.6071391105651855, -0.09412868320941925, 0.3831743896007538, 0.5150595903396606, 0.4826551079750061, -0.24247154593467712, 0.8821027278900146, 0.580203115940094, 0.6292230486869812, -0.10751114040613174, 0.394807368516922, 0.5195045471191406, 0.5112163424491882, -0.2650434076786041, 0.8475534915924072, 0.5802782773971558, 0.6212021112442017, -0.12096796184778214, 0.4070460796356201, 0.5240615606307983, 0.49785178899765015, -0.2654695510864258, 0.844110906124115, 0.5760892629623413, 0.599005937576294, -0.10190778970718384, 0.3975113332271576, 0.5204025506973267, 0.4905443489551544, -0.2438647300004959, 0.7850489616394043, 0.5116843581199646, 0.6170627474784851, 0.03641749545931816, 0.998455286026001, 0.4864588677883148, 0.6011449694633484, -0.0363389290869236, 0.9994176030158997, 0.5218768119812012, 0.70842444896698, -0.05242345854640007, 0.5637162923812866, 0.5038885474205017, 0.7153134942054749, -0.1649831235408783, 0.9865934252738953, 0.5056761503219604, 0.8804590702056885, -0.010637621395289898, 0.6473783254623413, 0.5054445266723633, 0.9102349877357483, -0.1348111927509308, 0.9735033512115479, 0.49667906761169434, 0.910010814666748, -0.008963512256741524, 0.6164994239807129, 0.49915724992752075, 0.9409347772598267, -0.13416655361652374, 0.9287875890731812, 0.5238301157951355, 0.9383440613746643, -0.060332201421260834, 0.736024022102356, 0.5237991213798523, 0.9628056287765503, -0.19374795258045197, 0.9712205529212952]
# [0.5454291105270386, 0.3704414367675781, -0.25374430418014526, 0.9987590312957764, 0.5500815510749817, 0.35554999113082886, -0.24365027248859406, 0.9988579750061035, 0.5510193109512329, 0.3591817021369934, -0.24372141063213348, 0.9987371563911438, 0.5522684454917908, 0.3615760803222656, -0.2437879741191864, 0.9986414313316345, 0.544561505317688, 0.3389837145805359, -0.2524881064891815, 0.9986942410469055, 0.5420867204666138, 0.33318257331848145, -0.2525475323200226, 0.9986754059791565, 0.5399174690246582, 0.3285142779350281, -0.25258341431617737, 0.9987735748291016, 0.5516723394393921, 0.3511846959590912, -0.16039316356182098, 0.997295081615448, 0.5360161066055298, 0.32650160789489746, -0.20084533095359802, 0.9988221526145935, 0.5441173911094666, 0.398624062538147, -0.2196078598499298, 0.9966263771057129, 0.5384232401847839, 0.391841322183609, -0.23137888312339783, 0.9980947971343994, 0.5554800033569336, 0.4236955940723419, -0.08016029000282288, 0.998623251914978, 0.5077985525131226, 0.39120087027549744, -0.17122580111026764, 0.9995156526565552, 0.5621804594993591, 0.503437876701355, -0.1251564919948578, 0.3421776592731476, 0.4923810362815857, 0.4665553569793701, -0.24950909614562988, 0.9555917382240295, 0.5769327878952026, 0.5832008719444275, -0.25203096866607666, 0.42072272300720215, 0.5111264586448669, 0.4796488285064697, -0.345155268907547, 0.8820325136184692, 0.582907497882843, 0.612297773361206, -0.27633142471313477, 0.4317839741706848, 0.5192732214927673, 0.5132219195365906, -0.37364938855171204, 0.8497493863105774, 0.5810248851776123, 0.6178886294364929, -0.2899032235145569, 0.4440028667449951, 0.5186271071434021, 0.4915090501308441, -0.3741377592086792, 0.8459872603416443, 0.577933669090271, 0.5904847979545593, -0.26117143034935, 0.4328555464744568, 0.5192161202430725, 0.48909488320350647, -0.3472242057323456, 0.7861307263374329, 0.5149067044258118, 0.6135858297348022, 0.03720327094197273, 0.9985803365707397, 0.4874241352081299, 0.601051926612854, -0.0371231809258461, 0.9994573593139648, 0.527824878692627, 0.7007925510406494, -0.04906843230128288, 0.5827534794807434, 0.5045087337493896, 0.7137894630432129, -0.18678350746631622, 0.9868482351303101, 0.5159860253334045, 0.8684494495391846, 0.038976214826107025, 0.659691333770752, 0.5046611428260803, 0.9152096509933472, -0.12782956659793854, 0.9747989773750305, 0.507672131061554, 0.8970212340354919, 0.04434477537870407, 0.6362418532371521, 0.4972550868988037, 0.9431124925613403, -0.12830685079097748, 0.9289481043815613, 0.5350210070610046, 0.9257332682609558, -0.009998518973588943, 0.7475598454475403, 0.5238582491874695, 0.9687132239341736, -0.19653773307800293, 0.9720207452774048]
# [0.5454466342926025, 0.3703721761703491, -0.22212529182434082, 0.9988815188407898, 0.5510692000389099, 0.34644877910614014, -0.2122344672679901, 0.9989708662033081, 0.5524557828903198, 0.3507046401500702, -0.2123037576675415, 0.9988619089126587, 0.5538825988769531, 0.35364070534706116, -0.21237607300281525, 0.998775839805603, 0.5441476106643677, 0.3381088674068451, -0.2185087502002716, 0.9988222718238831, 0.5416423082351685, 0.33319538831710815, -0.21854892373085022, 0.9988042116165161, 0.5403764247894287, 0.32121190428733826, -0.2185480147600174, 0.9988928437232971, 0.5534497499465942, 0.3484593331813812, -0.13209064304828644, 0.9975640177726746, 0.5356396436691284, 0.32237303256988525, -0.16154004633426666, 0.9989381432533264, 0.5447391271591187, 0.3981591463088989, -0.18958020210266113, 0.9969631433486938, 0.5384202599525452, 0.39038050174713135, -0.1980901062488556, 0.9982847571372986, 0.557922899723053, 0.4187389016151428, -0.06207890063524246, 0.9987599849700928, 0.5078597664833069, 0.3852723240852356, -0.13614436984062195, 0.99956214427948, 0.5640991926193237, 0.4947730302810669, -0.12422998249530792, 0.3971598744392395, 0.4918152391910553, 0.4665674865245819, -0.2049119472503662, 0.9534967541694641, 0.5789221525192261, 0.5751092433929443, -0.2672584354877472, 0.4704056680202484, 0.5129965543746948, 0.4793089032173157, -0.30452990531921387, 0.8823022842407227, 0.5857735872268677, 0.5970219969749451, -0.29492485523223877, 0.4795033633708954, 0.5143864154815674, 0.5066674947738647, -0.33118343353271484, 0.8522736430168152, 0.5856342911720276, 0.605738639831543, -0.3078147768974304, 0.4913327097892761, 0.5194636583328247, 0.4942023754119873, -0.33378154039382935, 0.8488968014717102, 0.582844614982605, 0.5897125601768494, -0.2764368951320648, 0.47939544916152954, 0.5205205082893372, 0.49200427532196045, -0.3071608245372772, 0.7901372909545898, 0.5176662802696228, 0.6122896671295166, 0.032029807567596436, 0.9987090229988098, 0.48821204900741577, 0.5994661450386047, -0.03184487670660019, 0.999504029750824, 0.5338593125343323, 0.683244526386261, -0.11062490940093994, 0.6136373281478882, 0.5047909021377563, 0.6940741539001465, -0.2301865518093109, 0.9876835346221924, 0.5283345580101013, 0.8502963185310364, -0.05844207480549812, 0.6800808310508728, 0.5036698579788208, 0.9153289198875427, -0.18730460107326508, 0.9763303399085999, 0.521216869354248, 0.8790742754936218, -0.0564529113471508, 0.6630089282989502, 0.49682560563087463, 0.9413735270500183, -0.18562431633472443, 0.9310420751571655, 0.5461896657943726, 0.9171206951141357, -0.11977341026067734, 0.7642647624015808, 0.5239454507827759, 0.9706794619560242, -0.2642815113067627, 0.9732750058174133]
# [0.5455344319343567, 0.3709465265274048, -0.1764029711484909, 0.9989800453186035, 0.5511910915374756, 0.34676769375801086, -0.1657865345478058, 0.9990490674972534, 0.5527457594871521, 0.35079994797706604, -0.16585339605808258, 0.9989465475082397, 0.5543502569198608, 0.3537566065788269, -0.16591426730155945, 0.9988691806793213, 0.5443653464317322, 0.3317391872406006, -0.17410996556282043, 0.9989044070243835, 0.5416187644004822, 0.3301578462123871, -0.17414629459381104, 0.998880922794342, 0.5398633480072021, 0.3228120505809784, -0.17416197061538696, 0.9989690780639648, 0.5528513789176941, 0.3649243414402008, -0.09659595042467117, 0.9977369904518127, 0.5356175303459167, 0.32401207089424133, -0.14443174004554749, 0.9990145564079285, 0.5446450710296631, 0.4014415442943573, -0.1485629677772522, 0.9972561001777649, 0.5384297966957092, 0.38942599296569824, -0.15922750532627106, 0.9984492063522339, 0.5529610514640808, 0.4461227059364319, -0.032804980874061584, 0.9988778829574585, 0.5058220028877258, 0.386104017496109, -0.13463345170021057, 0.9996013045310974, 0.5410959124565125, 0.5504295229911804, -0.074973925948143, 0.4079435467720032, 0.493499755859375, 0.49288854002952576, -0.14699998497962952, 0.9548165202140808, 0.5306710004806519, 0.5865604281425476, -0.1587143838405609, 0.4871390163898468, 0.5183738470077515, 0.5686673521995544, -0.17713433504104614, 0.8845102190971375, 0.5283058881759644, 0.6093314290046692, -0.18125669658184052, 0.49451547861099243, 0.5221854448318481, 0.6016326546669006, -0.19711072742938995, 0.8523268699645996, 0.5283833742141724, 0.5985996127128601, -0.17476144433021545, 0.5043187737464905, 0.5272991061210632, 0.5870213508605957, -0.1941886842250824, 0.8487967252731323, 0.5280323028564453, 0.5870675444602966, -0.15556640923023224, 0.490097314119339, 0.5260009169578552, 0.5765050649642944, -0.17593525350093842, 0.7921745777130127, 0.515605092048645, 0.6235587000846863, 0.03235580772161484, 0.9987806677818298, 0.48850589990615845, 0.6165279746055603, -0.032264500856399536, 0.9995279312133789, 0.5311893820762634, 0.7151445150375366, -0.04548909515142441, 0.6000375747680664, 0.5076835751533508, 0.7579839825630188, -0.2280593365430832, 0.9806451201438904, 0.5274215936660767, 0.8519895076751709, 0.08038800954818726, 0.6588160395622253, 0.5144186615943909, 0.9137210249900818, -0.06556568294763565, 0.9605137705802917, 0.5215007662773132, 0.8784683346748352, 0.08959001302719116, 0.6461542248725891, 0.5108634829521179, 0.9328815340995789, -0.055048488080501556, 0.9057922959327698, 0.5369812250137329, 0.9130458831787109, 0.05512024834752083, 0.7417463064193726, 0.5282670855522156, 0.9605337381362915, -0.10221806913614273, 0.9592798948287964]
# [0.5455425381660461, 0.3718101978302002, -0.15469293296337128, 0.9990524649620056, 0.5510607957839966, 0.35926732420921326, -0.1429026871919632, 0.9990835785865784, 0.5524141192436218, 0.3643057346343994, -0.14294014871120453, 0.9989808797836304, 0.5539035201072693, 0.36704590916633606, -0.142966166138649, 0.998908281326294, 0.5442976951599121, 0.33586665987968445, -0.15108343958854675, 0.99895179271698, 0.5415656566619873, 0.3305337131023407, -0.15113672614097595, 0.9989285469055176, 0.5396043658256531, 0.3234933018684387, -0.15118956565856934, 0.9990261793136597, 0.5521461963653564, 0.372488409280777, -0.07945986092090607, 0.9977139234542847, 0.5354804396629333, 0.3299540579319, -0.12056276947259903, 0.9990592002868652, 0.5446137189865112, 0.40345725417137146, -0.13010820746421814, 0.9974836111068726, 0.5384281873703003, 0.3888692855834961, -0.14107482135295868, 0.9985843896865845, 0.5517239570617676, 0.44209519028663635, -0.015821097418665886, 0.9989709258079529, 0.50560462474823, 0.38920462131500244, -0.12393341958522797, 0.9996377229690552, 0.5366779565811157, 0.5511963963508606, -0.003030452411621809, 0.3955569565296173, 0.4915488362312317, 0.5093103647232056, -0.13153240084648132, 0.9566321969032288, 0.5248520374298096, 0.583768367767334, -0.04894974082708359, 0.4789349436759949, 0.5140151381492615, 0.5932355523109436, -0.14969006180763245, 0.8846924304962158, 0.5230039358139038, 0.6104465126991272, -0.0573081374168396, 0.48527270555496216, 0.5167921781539917, 0.6264036297798157, -0.1672779619693756, 0.8499792218208313, 0.5232237577438354, 0.5954121351242065, -0.06410996615886688, 0.4933144152164459, 0.523855984210968, 0.6143554449081421, -0.16424252092838287, 0.8461607098579407, 0.5233321189880371, 0.5854013562202454, -0.05248526856303215, 0.4779486060142517, 0.5223735570907593, 0.6023897528648376, -0.14802268147468567, 0.7911425232887268, 0.5142601728439331, 0.626095712184906, 0.03319155424833298, 0.998765230178833, 0.48863935470581055, 0.6218141317367554, -0.0331239327788353, 0.999546229839325, 0.5298757553100586, 0.7115589380264282, -0.0017740450566634536, 0.5727913975715637, 0.5079052448272705, 0.7532793283462524, -0.18402376770973206, 0.9783064723014832, 0.5273195505142212, 0.852315366268158, 0.06885035336017609, 0.6372184753417969, 0.5129278898239136, 0.9298073649406433, -0.14444132149219513, 0.9599945545196533, 0.5216243863105774, 0.8788483142852783, 0.07456069439649582, 0.6348394155502319, 0.5084232687950134, 0.9490193724632263, -0.1432497203350067, 0.9042273759841919, 0.535812258720398, 0.9091883301734924, 0.03793705627322197, 0.7266204953193665, 0.5278573632240295, 0.9659691452980042, -0.20305046439170837, 0.9589012265205383]
# [0.5464556217193604, 0.3398768901824951, -0.1812262088060379, 0.9991106986999512, 0.5518856048583984, 0.3270714581012726, -0.16931837797164917, 0.9990978240966797, 0.5538593530654907, 0.32968711853027344, -0.16936196386814117, 0.9989853501319885, 0.5558867454528809, 0.33208656311035156, -0.1694030463695526, 0.998917281627655, 0.5452796220779419, 0.31710875034332275, -0.17758598923683167, 0.9989737868309021, 0.542048990726471, 0.30494964122772217, -0.17763610184192657, 0.9989476203918457, 0.5397725701332092, 0.3029451072216034, -0.17768456041812897, 0.9990635514259338, 0.5540277361869812, 0.33760523796081543, -0.1004839688539505, 0.99761962890625, 0.5353503227233887, 0.32081684470176697, -0.13881558179855347, 0.9990849494934082, 0.5454655885696411, 0.3811322748661041, -0.15420450270175934, 0.9976873397827148, 0.5392981767654419, 0.35768458247184753, -0.16527557373046875, 0.9987058043479919, 0.5507605075836182, 0.4195469319820404, -0.03148092329502106, 0.9990564584732056, 0.5059327483177185, 0.37512004375457764, -0.1355588734149933, 0.9996685981750488, 0.5388892889022827, 0.5410688519477844, -0.016630031168460846, 0.3873446583747864, 0.4918456971645355, 0.5053555965423584, -0.14636334776878357, 0.9581254124641418, 0.5259703397750854, 0.5791680812835693, -0.07533052563667297, 0.46775713562965393, 0.5135107636451721, 0.5948759317398071, -0.17019277811050415, 0.8841387033462524, 0.5251584053039551, 0.6069673299789429, -0.08680877089500427, 0.4728039503097534, 0.5159251689910889, 0.6302221417427063, -0.18951241672039032, 0.8465278148651123, 0.5247674584388733, 0.5941522121429443, -0.09392909705638885, 0.4787490665912628, 0.5235000848770142, 0.6187071800231934, -0.18798305094242096, 0.8424152731895447, 0.5246872901916504, 0.5852344632148743, -0.07951818406581879, 0.463234543800354, 0.5221309661865234, 0.6056857109069824, -0.16928070783615112, 0.7892221212387085, 0.515689492225647, 0.6128372550010681, 0.03404691070318222, 0.9987433552742004, 0.4905011057853699, 0.6136330962181091, -0.03396804630756378, 0.9995378851890564, 0.5317193865776062, 0.7042438387870789, 0.0033952458761632442, 0.5448513627052307, 0.507921040058136, 0.7438948154449463, -0.15127506852149963, 0.9696570038795471, 0.5284563899040222, 0.8521031141281128, 0.08339004218578339, 0.6069563031196594, 0.5117566585540771, 0.9207494854927063, -0.09625204652547836, 0.9524197578430176, 0.5224704146385193, 0.8787590861320496, 0.08965537697076797, 0.6118329763412476, 0.5065180659294128, 0.9423078298568726, -0.0916425958275795, 0.8896477818489075, 0.5351313948631287, 0.9118451476097107, 0.053120680153369904, 0.7006994485855103, 0.5285899043083191, 0.9607535004615784, -0.15127742290496826, 0.952503502368927]
# [0.5484456419944763, 0.30688732862472534, -0.27200570702552795, 0.9990686178207397, 0.5540002584457397, 0.2865285575389862, -0.2627549469470978, 0.9988901615142822, 0.5561716556549072, 0.28905463218688965, -0.2627994120121002, 0.9987390637397766, 0.5583246350288391, 0.284473180770874, -0.26285237073898315, 0.9986715912818909, 0.5466469526290894, 0.27878236770629883, -0.26963356137275696, 0.998729944229126, 0.5435405969619751, 0.2757969796657562, -0.2696962356567383, 0.9986570477485657, 0.5408703088760376, 0.27516472339630127, -0.26975828409194946, 0.9988611936569214, 0.5590945482254028, 0.3017444312572479, -0.18712325394153595, 0.997066080570221, 0.536251425743103, 0.2779148817062378, -0.21829228103160858, 0.998836874961853, 0.5506114363670349, 0.3409312963485718, -0.24074526131153107, 0.997817873954773, 0.5415381193161011, 0.3303869664669037, -0.24989791214466095, 0.9987833499908447, 0.5647872686386108, 0.3642549514770508, -0.11049123853445053, 0.9991305470466614, 0.5076622366905212, 0.34484413266181946, -0.18614214658737183, 0.9996925592422485, 0.5452204942703247, 0.5161391496658325, -0.1088663712143898, 0.40203434228897095, 0.4938746988773346, 0.4954874515533447, -0.18577803671360016, 0.9580196142196655, 0.527766764163971, 0.5777742862701416, -0.17717865109443665, 0.46074560284614563, 0.5153080224990845, 0.5766743421554565, -0.21037712693214417, 0.8812929391860962, 0.5275648832321167, 0.6049090623855591, -0.19630905985832214, 0.4629214107990265, 0.5183376669883728, 0.61076420545578, -0.2304789274930954, 0.8413347601890564, 0.5253959894180298, 0.5939984321594238, -0.20422036945819855, 0.4666807949542999, 0.5246052742004395, 0.5955591201782227, -0.23611721396446228, 0.8370533585548401, 0.5253601670265198, 0.5793976783752441, -0.18188029527664185, 0.451359361410141, 0.5235188007354736, 0.5837742686271667, -0.21217484772205353, 0.7837369441986084, 0.5246921181678772, 0.5633354783058167, 0.0280894935131073, 0.9986842274665833, 0.49470192193984985, 0.5805420279502869, -0.028048664331436157, 0.9994954466819763, 0.5406319499015808, 0.6645166277885437, -0.013793088495731354, 0.5369530916213989, 0.5080294013023376, 0.7388656139373779, -0.12863531708717346, 0.9503593444824219, 0.538482129573822, 0.8255617022514343, 0.08381753414869308, 0.5846250653266907, 0.5081810355186462, 0.9152233600616455, -0.042320020496845245, 0.9321765899658203, 0.5325769186019897, 0.8499464392662048, 0.09171886742115021, 0.5950191020965576, 0.5037068724632263, 0.9394397139549255, -0.03496607393026352, 0.8556156754493713, 0.5421167016029358, 0.9008638858795166, 0.045185789465904236, 0.6820477247238159, 0.5241873264312744, 0.9627349376678467, -0.10604486614465714, 0.9356811046600342]
# [0.5475199222564697, 0.3213474154472351, -0.2412673979997635, 0.9991387128829956, 0.5511633157730103, 0.29935070872306824, -0.22843989729881287, 0.9989649653434753, 0.5541800260543823, 0.30105212330818176, -0.22848889231681824, 0.9988114237785339, 0.5572760105133057, 0.3010158836841583, -0.22853171825408936, 0.9987474679946899, 0.5436291694641113, 0.29304221272468567, -0.23604917526245117, 0.9988263845443726, 0.5406714677810669, 0.29010698199272156, -0.23613867163658142, 0.9987599849700928, 0.5377686023712158, 0.28789934515953064, -0.23620359599590302, 0.9989553093910217, 0.5583658218383789, 0.30919015407562256, -0.1486978679895401, 0.9971528053283691, 0.5317825078964233, 0.2901327908039093, -0.18424926698207855, 0.998935878276825, 0.5497795939445496, 0.34305718541145325, -0.20980092883110046, 0.9980093240737915, 0.5391440987586975, 0.335162878036499, -0.22010588645935059, 0.9988970756530762, 0.5595176219940186, 0.38534966111183167, -0.06703473627567291, 0.9991526007652283, 0.5065670609474182, 0.358542263507843, -0.16604964435100555, 0.9997210502624512, 0.5284170508384705, 0.517481803894043, -0.06954585015773773, 0.38397955894470215, 0.4825032353401184, 0.4947773814201355, -0.1802334487438202, 0.9615258574485779, 0.5131161212921143, 0.5785977840423584, -0.11731350421905518, 0.4402209520339966, 0.4864133894443512, 0.5851176381111145, -0.21998736262321472, 0.8899322748184204, 0.5096598863601685, 0.6070265769958496, -0.1283763349056244, 0.4442805051803589, 0.48325127363204956, 0.6172537207603455, -0.24309666454792023, 0.851477861404419, 0.5106867551803589, 0.5964539051055908, -0.14272184669971466, 0.4474278390407562, 0.4913969039916992, 0.6105762720108032, -0.24649517238140106, 0.8477864861488342, 0.5105477571487427, 0.5834560990333557, -0.12444895505905151, 0.43253010511398315, 0.49271059036254883, 0.5995038151741028, -0.22170111536979675, 0.798803985118866, 0.5223220586776733, 0.5792110562324524, 0.028562450781464577, 0.9986607432365417, 0.4943198561668396, 0.5847090482711792, -0.028334911912679672, 0.9995184540748596, 0.5159353613853455, 0.7006971836090088, -0.0617164671421051, 0.5353063344955444, 0.5075381994247437, 0.7015571594238281, -0.22463861107826233, 0.9525443315505981, 0.506547212600708, 0.8841000199317932, 0.026184385642409325, 0.5772373676300049, 0.5084999799728394, 0.9294227361679077, -0.1837312877178192, 0.9357223510742188, 0.5022360682487488, 0.9093554615974426, 0.032851412892341614, 0.6042118668556213, 0.505595326423645, 0.9509998559951782, -0.18047311902046204, 0.8640480637550354, 0.5170308351516724, 0.948093593120575, -0.01739741489291191, 0.6733460426330566, 0.5247704982757568, 0.9652592539787292, -0.2532649636268616, 0.9378346800804138]
# ...
# [0.5265033841133118, 0.31829696893692017, -0.058952696621418, 0.9993601441383362, 0.5354714393615723, 0.3092151880264282, -0.0656118243932724, 0.9994714856147766, 0.5373284816741943, 0.312895268201828, -0.06568244099617004, 0.9994387626647949, 0.5393414497375488, 0.31737807393074036, -0.06575920432806015, 0.9994208216667175, 0.5324918031692505, 0.3039456903934479, -0.049556221812963486, 0.9993855953216553, 0.5321286916732788, 0.30337050557136536, -0.0495494119822979, 0.9992176294326782, 0.5317379832267761, 0.30280882120132446, -0.049593400210142136, 0.9992579817771912, 0.5463715195655823, 0.3437861204147339, -0.0636078268289566, 0.9993352890014648, 0.5385028719902039, 0.3240277171134949, 0.009084155783057213, 0.9994526505470276, 0.5272928476333618, 0.3422711491584778, -0.0554802305996418, 0.9993743896484375, 0.5238690376281738, 0.33563587069511414, -0.03477267548441887, 0.9994204640388489, 0.5447056889533997, 0.4455856680870056, -0.09790472686290741, 0.999014139175415, 0.5139673948287964, 0.4060852527618408, 0.06490044295787811, 0.9993429780006409, 0.5045253038406372, 0.44241780042648315, -0.17277425527572632, 0.8153061866760254, 0.48441457748413086, 0.459975004196167, 0.06814448535442352, 0.6557403206825256, 0.4807731509208679, 0.3675617575645447, -0.15952187776565552, 0.8145958185195923, 0.47195157408714294, 0.3919996917247772, 5.4766998800914735e-05, 0.8318368196487427, 0.47345271706581116, 0.35743600130081177, -0.17353355884552002, 0.7976000308990479, 0.46759241819381714, 0.3779638409614563, -0.010895911604166031, 0.8148919939994812, 0.4772927761077881, 0.3339514136314392, -0.17665503919124603, 0.7971646785736084, 0.472644180059433, 0.3738882839679718, -0.012703076004981995, 0.8171799182891846, 0.4788493514060974, 0.3437982499599457, -0.15956750512123108, 0.7801469564437866, 0.4760635793209076, 0.38177722692489624, -0.004304804373532534, 0.8034723401069641, 0.5019431114196777, 0.7547774314880371, -0.02910025790333748, 0.9976353645324707, 0.47474756836891174, 0.7260788679122925, 0.029064808040857315, 0.9982882738113403, 0.5025683045387268, 0.9786035418510437, -0.0759824588894844, 0.49657994508743286, 0.45387616753578186, 0.9189774394035339, 0.019406849518418312, 0.5796827673912048, 0.4916840195655823, 1.1407520771026611, 0.09482625126838684, 0.15808090567588806, 0.4636434018611908, 1.1369651556015015, 0.11462891101837158, 0.34013110399246216, 0.4922139048576355, 1.1517897844314575, 0.11282936483621597, 0.22382399439811707, 0.46824175119400024, 1.164537787437439, 0.12415902316570282, 0.3405875265598297, 0.48101258277893066, 1.2135428190231323, 0.0830545574426651, 0.17522096633911133, 0.4518223702907562, 1.2197260856628418, 0.08344026654958725, 0.3047630488872528]
# [0.5260518193244934, 0.31276124715805054, -0.05215790867805481, 0.9993174076080322, 0.534981906414032, 0.30425816774368286, -0.06308624893426895, 0.9994356632232666, 0.5368090867996216, 0.30769822001457214, -0.06317206472158432, 0.9994080662727356, 0.5387915968894958, 0.3116115629673004, -0.06325735151767731, 0.9993880987167358, 0.5322303175926208, 0.29904165863990784, -0.04672222211956978, 0.999348521232605, 0.5319842100143433, 0.2984648048877716, -0.04670048505067825, 0.9991555213928223, 0.531710147857666, 0.2979223430156708, -0.04679184406995773, 0.999191403388977, 0.5461298227310181, 0.33771076798439026, -0.06623207032680511, 0.9993522763252258, 0.5385189056396484, 0.3208087086677551, 0.013152755796909332, 0.999410092830658, 0.5267003178596497, 0.33661383390426636, -0.052860699594020844, 0.9993482232093811, 0.5234651565551758, 0.3299133777618408, -0.03092769905924797, 0.9993847608566284, 0.5446982979774475, 0.44262072443962097, -0.09703397005796432, 0.9988976716995239, 0.5152921080589294, 0.404058575630188, 0.06521553546190262, 0.9993185997009277, 0.498593807220459, 0.44570714235305786, -0.1453239619731903, 0.8315930366516113, 0.4844876825809479, 0.46001049876213074, 0.08293081820011139, 0.635465145111084, 0.4789462089538574, 0.3589060306549072, -0.12422959506511688, 0.8309987187385559, 0.47189393639564514, 0.38774073123931885, 0.024924883618950844, 0.8282685279846191, 0.472221702337265, 0.342733770608902, -0.13759015500545502, 0.8142269849777222, 0.46588554978370667, 0.37621361017227173, 0.01502344198524952, 0.8129353523254395, 0.47722235321998596, 0.3267590403556824, -0.13913777470588684, 0.8137038350105286, 0.47067752480506897, 0.3705419600009918, 0.009708551689982414, 0.815463125705719, 0.4786689877510071, 0.3375895023345947, -0.12312875688076019, 0.7967545390129089, 0.47435516119003296, 0.37957748770713806, 0.01927272044122219, 0.8022930026054382, 0.5019249320030212, 0.7538194060325623, -0.026684824377298355, 0.9966940879821777, 0.4742724299430847, 0.7239241600036621, 0.026694735512137413, 0.9981036186218262, 0.5073549151420593, 0.9796434640884399, -0.08188946545124054, 0.5234110355377197, 0.44845137000083923, 0.8900954723358154, -0.027049291878938675, 0.6079692244529724, 0.4962444305419922, 1.1312522888183594, 0.09099338948726654, 0.15536120533943176, 0.45880356431007385, 1.1199465990066528, 0.06508152186870575, 0.3562173843383789, 0.49446892738342285, 1.135513186454773, 0.10860233008861542, 0.21831737458705902, 0.464412122964859, 1.1494616270065308, 0.07431454211473465, 0.34857890009880066, 0.48871850967407227, 1.209446668624878, 0.08081713318824768, 0.1688683182001114, 0.4454757571220398, 1.2051568031311035, 0.03455381467938423, 0.30871766805648804]
# [0.5255152583122253, 0.3094397783279419, -0.04625837504863739, 0.9992350935935974, 0.5342949628829956, 0.3006698489189148, -0.05976853892207146, 0.9993529915809631, 0.5361109972000122, 0.3037869930267334, -0.05983629822731018, 0.9993308186531067, 0.538072943687439, 0.3072591722011566, -0.059901826083660126, 0.9993061423301697, 0.5317740440368652, 0.2959778308868408, -0.04047383368015289, 0.9992616772651672, 0.5316537618637085, 0.29552680253982544, -0.04044568911194801, 0.9990301132202148, 0.5315045118331909, 0.295125812292099, -0.04053996875882149, 0.9990665316581726, 0.5459362268447876, 0.3327791094779968, -0.0652850791811943, 0.9993343353271484, 0.5385321378707886, 0.31825560331344604, 0.015094888396561146, 0.9993069171905518, 0.5261754989624023, 0.33299723267555237, -0.051051996648311615, 0.999281108379364, 0.5231679081916809, 0.32681846618652344, -0.02543557807803154, 0.9993037581443787, 0.5449541807174683, 0.4417100250720978, -0.09634536504745483, 0.9987870454788208, 0.5150310397148132, 0.4028584957122803, 0.06690271943807602, 0.9992842078208923, 0.49765342473983765, 0.4505583941936493, -0.13833202421665192, 0.8459104895591736, 0.48380106687545776, 0.4643498361110687, 0.09223610162734985, 0.6188568472862244, 0.4755333960056305, 0.3565562963485718, -0.12009550631046295, 0.8454602360725403, 0.47013965249061584, 0.3833969235420227, 0.03724145144224167, 0.8257700204849243, 0.46780499815940857, 0.33902984857559204, -0.1332360804080963, 0.8287423849105835, 0.4648961126804352, 0.37254610657691956, 0.027752548456192017, 0.8114102482795715, 0.47395044565200806, 0.3241468071937561, -0.13410770893096924, 0.8280709385871887, 0.46906548738479614, 0.36388325691223145, 0.022138705477118492, 0.8139529228210449, 0.4760574400424957, 0.33514249324798584, -0.11855120956897736, 0.8108903169631958, 0.47280845046043396, 0.37447884678840637, 0.0315825417637825, 0.800825834274292, 0.5019130110740662, 0.7535241842269897, -0.026040714234113693, 0.9959911108016968, 0.4738229215145111, 0.7236962914466858, 0.026061031967401505, 0.9979859590530396, 0.5088294744491577, 0.9801009893417358, -0.08348731696605682, 0.5511734485626221, 0.4462861120700836, 0.8854969143867493, -0.038694001734256744, 0.6359907984733582, 0.4988892078399658, 1.1305286884307861, 0.09214042127132416, 0.1553693264722824, 0.4555736184120178, 1.1169072389602661, 0.05242962762713432, 0.3757631778717041, 0.49686509370803833, 1.1326756477355957, 0.10995068401098251, 0.21358011662960052, 0.46122923493385315, 1.1462881565093994, 0.06138109043240547, 0.3575786352157593, 0.4917677342891693, 1.2082103490829468, 0.08255252242088318, 0.16490547358989716, 0.44206923246383667, 1.2035616636276245, 0.02045300230383873, 0.316959410905838]
# [0.5253260135650635, 0.309295654296875, -0.042739953845739365, 0.9991939067840576, 0.5340294241905212, 0.30060404539108276, -0.05505552887916565, 0.9993109703063965, 0.5358034372329712, 0.3037014305591583, -0.05511188507080078, 0.9992921948432922, 0.537697434425354, 0.3071446120738983, -0.05516964942216873, 0.9992656111717224, 0.5316654443740845, 0.29596441984176636, -0.035747867077589035, 0.9992159605026245, 0.5316053628921509, 0.2955341935157776, -0.035718537867069244, 0.9989606738090515, 0.5315067768096924, 0.29516229033470154, -0.03579876944422722, 0.9989996552467346, 0.5456132292747498, 0.3322039544582367, -0.06254284828901291, 0.9993325471878052, 0.5385223031044006, 0.3179628252983093, 0.016118275001645088, 0.9992437958717346, 0.5258864164352417, 0.33253857493400574, -0.04708843678236008, 0.9992492198944092, 0.5230173468589783, 0.3264949321746826, -0.021433260291814804, 0.9992610812187195, 0.5451281070709229, 0.4416743814945221, -0.09477804601192474, 0.9987355470657349, 0.5148560404777527, 0.40329986810684204, 0.06779108941555023, 0.9992721080780029, 0.49677473306655884, 0.4511201083660126, -0.13918766379356384, 0.8591300845146179, 0.4833603799343109, 0.4657038152217865, 0.08118316531181335, 0.6086713671684265, 0.47298192977905273, 0.3545387387275696, -0.13080355525016785, 0.8589210510253906, 0.46872884035110474, 0.3807620108127594, 0.0063649676740169525, 0.8269574642181396, 0.46499061584472656, 0.336780309677124, -0.14567235112190247, 0.8425572514533997, 0.46415361762046814, 0.3672519028186798, -0.006044378504157066, 0.8136089444160461, 0.471205472946167, 0.32176047563552856, -0.14557117223739624, 0.8417928218841553, 0.46805906295776367, 0.356675922870636, -0.01184001099318266, 0.8161184191703796, 0.4732922911643982, 0.3325778543949127, -0.12916122376918793, 0.824679970741272, 0.47187453508377075, 0.368741899728775, 0.00015592601266689599, 0.8031063079833984, 0.5019070506095886, 0.753404438495636, -0.025587445124983788, 0.9955446720123291, 0.4737115800380707, 0.7237148880958557, 0.025610897690057755, 0.9979519248008728, 0.5091381669044495, 0.9802801609039307, -0.09087606519460678, 0.5759766101837158, 0.4453829228878021, 0.8762176632881165, -0.0552901029586792, 0.6604287028312683, 0.4999719560146332, 1.1263543367385864, 0.08853805065155029, 0.1558838039636612, 0.45513543486595154, 1.1124401092529297, 0.03233250603079796, 0.3931577205657959, 0.49815768003463745, 1.1272621154785156, 0.10639554262161255, 0.21117766201496124, 0.4610152244567871, 1.1418744325637817, 0.04101889207959175, 0.3663892447948456, 0.4935137629508972, 1.2063124179840088, 0.08049207925796509, 0.16154789924621582, 0.4418322443962097, 1.2013388872146606, 0.0005409281002357602, 0.3250023424625397]
# [0.5250710844993591, 0.30974769592285156, -0.034168653190135956, 0.9991774559020996, 0.5337362885475159, 0.3009938895702362, -0.0459684394299984, 0.9992941617965698, 0.5355234146118164, 0.30411210656166077, -0.04602203518152237, 0.99927818775177, 0.5374301671981812, 0.3075979948043823, -0.046081457287073135, 0.9992532134056091, 0.5314483642578125, 0.29634717106819153, -0.027085503563284874, 0.9991970062255859, 0.5314449667930603, 0.2959164083003998, -0.02705385349690914, 0.9989265203475952, 0.5314117670059204, 0.2955479025840759, -0.027118708938360214, 0.9989671111106873, 0.5455038547515869, 0.33250388503074646, -0.06091472506523132, 0.9993452429771423, 0.5385270118713379, 0.31812766194343567, 0.021280230954289436, 0.9992143511772156, 0.5256094336509705, 0.3328861594200134, -0.038112618029117584, 0.9992265701293945, 0.5227926969528198, 0.32686251401901245, -0.013274766504764557, 0.9992274641990662, 0.5450877547264099, 0.4413999617099762, -0.09393514692783356, 0.9986920952796936, 0.5163376331329346, 0.4034557342529297, 0.07237421721220016, 0.9992719292640686, 0.4942495822906494, 0.4502122104167938, -0.12884822487831116, 0.870830237865448, 0.48542356491088867, 0.4659043550491333, 0.10985738039016724, 0.5966323614120483, 0.4704636037349701, 0.3516702950000763, -0.10118512064218521, 0.8705549240112305, 0.46877914667129517, 0.3813348412513733, 0.07113263010978699, 0.8268191814422607, 0.4624910354614258, 0.3335086703300476, -0.11264197528362274, 0.8542428612709045, 0.4641411304473877, 0.3653872013092041, 0.06477692723274231, 0.814332902431488, 0.4686165750026703, 0.3194900155067444, -0.11368105560541153, 0.8534104228019714, 0.46783050894737244, 0.3547753095626831, 0.057770103216171265, 0.8170130848884583, 0.47082096338272095, 0.33057940006256104, -0.09946508705615997, 0.8363362550735474, 0.47170114517211914, 0.3675282299518585, 0.06539286673069, 0.8042792677879333, 0.5018872022628784, 0.7529183030128479, -0.025808880105614662, 0.9951857328414917, 0.47384342551231384, 0.7236336469650269, 0.02583644911646843, 0.9979137778282166, 0.5090304017066956, 0.9807742238044739, -0.0988716334104538, 0.5910095572471619, 0.44630223512649536, 0.8774462938308716, -0.045182425528764725, 0.6778535842895508, 0.4996134340763092, 1.123131275177002, 0.07165248692035675, 0.15259063243865967, 0.45590272545814514, 1.1114245653152466, 0.040039725601673126, 0.39991629123687744, 0.49829286336898804, 1.1241949796676636, 0.0888417512178421, 0.2077365517616272, 0.46152597665786743, 1.1400638818740845, 0.04847140237689018, 0.36992254853248596, 0.4924970269203186, 1.2051247358322144, 0.06899726390838623, 0.15649989247322083, 0.4426703453063965, 1.2009029388427734, 0.013997125439345837, 0.324923574924469]

# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('coords.csv')

# %%
df.head()
# Out:
#       class        x1        y1        z1        v1        x2        y2  \
# 0  Cut Shot  0.225457  0.162047 -0.370667  0.999314  0.228338  0.144807
# 1  Cut Shot  0.226766  0.160576 -0.416613  0.999288  0.231159  0.143220
# 2  Cut Shot  0.227436  0.159746 -0.411580  0.999221  0.232215  0.142140
# 3  Cut Shot  0.229538  0.157380 -0.456491  0.999209  0.235132  0.140172
# 4  Cut Shot  0.232534  0.157470 -0.412577  0.999266  0.238301  0.139947
#
#          z2        v2        x3  ...       z31       v31       x32       y32  \
# 0 -0.393244  0.999527  0.232583  ...  0.020360  0.786419  0.296267  0.607939
# 1 -0.432315  0.999506  0.235892  ... -0.009923  0.781169  0.297536  0.608159
# 2 -0.427828  0.999435  0.237021  ... -0.025035  0.775278  0.299671  0.608248
# 3 -0.469767  0.999416  0.240705  ... -0.050908  0.767133  0.299943  0.619371
# 4 -0.415865  0.999456  0.244729  ... -0.079229  0.752655  0.299295  0.617866
#
#         z32       v32       x33       y33       z33       v33
# 0 -0.612369  0.985078  0.365552  0.605348 -0.107639  0.878047
# 1 -0.511280  0.983190  0.363404  0.603490 -0.137089  0.874082
# 2 -0.483309  0.981494  0.360223  0.600096 -0.148503  0.870491
# 3 -0.446977  0.978368  0.356859  0.605373 -0.173162  0.864483
# 4 -0.463095  0.976094  0.358085  0.598942 -0.190293  0.854238
#
# [5 rows x 133 columns]

# %%
X = df.drop('class', axis=1) # features
y = df['class'] # target value

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1234)

# %%
y_test
# Out:
# 1658     Sweep Shot
# 541        Cut Shot
# 1413     Sweep Shot
# 1545     Sweep Shot
# 222        Cut Shot
#            ...
# 1443     Sweep Shot
# 638     Lofted Shot
# 1575     Sweep Shot
# 587        Cut Shot
# 599        Cut Shot
# Name: class, Length: 516, dtype: object

# %%
from sklearn.pipeline import make_pipeline 
from sklearn.preprocessing import StandardScaler 

from sklearn.linear_model import LogisticRegression, RidgeClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier

# %%
pipelines = {
    'lr':make_pipeline(StandardScaler(), LogisticRegression()),
    'rc':make_pipeline(StandardScaler(), RidgeClassifier()),
    'rf':make_pipeline(StandardScaler(), RandomForestClassifier()),
    'gb':make_pipeline(StandardScaler(), GradientBoostingClassifier()),
}

# %%
fit_models = {}
for algo, pipeline in pipelines.items():
    model = pipeline.fit(X_train, y_train)
    fit_models[algo] = model
# Out:
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
fit_models
# Out:
# {'lr': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('logisticregression', LogisticRegression())]),
#  'rc': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('ridgeclassifier', RidgeClassifier())]),
#  'rf': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('randomforestclassifier', RandomForestClassifier())]),
#  'gb': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('gradientboostingclassifier', GradientBoostingClassifier())])}

# %%
fit_models['rc'].predict(X_test)
# Out:
# array(['Cut Shot', 'Cut Shot', 'Cut Shot', 'Cut Shot', 'Cut Shot',
#        'Cut Shot', 'Cut Shot', 'Cut Shot', 'Cut Shot', 'Cut Shot',
#        'Cut Shot', 'Cut Shot', 'Straight Drive', 'Cut Shot', 'Cut Shot',
#        'Cut Shot', 'Cut Shot', 'Straight Drive', 'Cut Shot', 'Cut Shot',
#        'Cut Shot', 'Cut Shot', 'Cut Shot', 'Cut Shot', 'Straight Drive',
#        'Cut Shot', 'Cut Shot', 'Straight Drive', 'Cut Shot',
#        'Straight Drive', 'Cut Shot', 'Cut Shot', 'Cut Shot', 'Cut Shot',
#        'Straight Drive', 'Cut Shot', 'Straight Drive', 'Straight Drive',
#        'Cut Shot', 'Cut Shot', 'Cut Shot', 'Cut Shot', 'Cut Shot',
#        'Straight Drive', 'Cut Shot', 'Cut Shot', 'Cut Shot', 'Cut Shot',
#        'Cut Shot', 'Cut Shot', 'Cut Shot', 'Cut Shot', 'Cut Shot',
#        'Cut Shot', 'Cut Shot', 'Cut Shot', 'Cut Shot', 'Straight Drive',
#        'Cut Shot', 'Cut Shot', 'Cut Shot', 'Cut Shot', 'Cut Shot',
#        'Cut Shot', 'Cut Shot', 'Cut Shot', 'Cut Shot', 'Cut Shot',
#        'Straight Drive', 'Cut Shot', 'Cut Shot', 'Cut Shot', 'Cut Shot',
#        'Cut Shot', 'Cut Shot', 'Cut Shot', 'Straight Drive', 'Cut Shot',
#        'Cut Shot', 'Cut Shot', 'Cut Shot', 'Cut Shot', 'Cut Shot',
#        'Cut Shot', 'Cut Shot', 'Cut Shot', 'Cut Shot', 'Cut Shot',
#        'Cut Shot', 'Cut Shot', 'Cut Shot', 'Cut Shot', 'Cut Shot',
#        'Cut Shot', 'Cut Shot', 'Cut Shot', 'Cut Shot', 'Cut Shot',
#        'Cut Shot', 'Cut Shot', 'Cut Shot', 'Cut Shot', 'Cut Shot',
#        'Cut Shot', 'Cut Shot', 'Cut Shot', 'Cut Shot', 'Cut Shot',
#        'Cut Shot', 'Cut Shot', 'Cut Shot', 'Cut Shot', 'Cut Shot',
#        'Cut Shot', 'Cut Shot', 'Cut Shot', 'Cut Shot', 'Cut Shot',
#        'Cut Shot', 'Cut Shot', 'Cut Shot', 'Straight Drive', 'Cut Shot',
#        'Cut Shot', 'Cut Shot', 'Cut Shot', 'Cut Shot', 'Cut Shot',
#        'Straight Drive', 'Cut Shot', 'Straight Drive', 'Cut Shot',
#        'Cut Shot', 'Cut Shot', 'Cut Shot', 'Cut Shot', 'Cut Shot',
#        'Cut Shot', 'Cut Shot', 'Cut Shot', 'Cut Shot', 'Cut Shot',
#        'Straight Drive', 'Cut Shot', 'Cut Shot', 'Cut Shot', 'Cut Shot',
#        'Cut Shot', 'Cut Shot', 'Cut Shot', 'Cut Shot', 'Cut Shot',
#        'Cut Shot', 'Cut Shot', 'Cut Shot', 'Cut Shot', 'Straight Drive',
#        'Cut Shot', 'Cut Shot', 'Cut Shot', 'Cut Shot', 'Cut Shot',
#        'Straight Drive', 'Cut Shot', 'Cut Shot', 'Cut Shot', 'Cut Shot',
#        'Cut Shot', 'Cut Shot', 'Cut Shot', 'Cut Shot', 'Straight Drive',
#        'Cut Shot', 'Cut Shot', 'Cut Shot', 'Cut Shot', 'Cut Shot',
#        'Cut Shot', 'Cut Shot', 'Cut Shot', 'Cut Shot', 'Cut Shot',
#        'Cut Shot', 'Straight Drive', 'Cut Shot', 'Cut Shot', 'Cut Shot',
#        'Cut Shot', 'Cut Shot', 'Cut Shot', 'Cut Shot', 'Cut Shot',
#        'Straight Drive', 'Cut Shot', 'Cut Shot', 'Cut Shot', 'Cut Shot',
#        'Cut Shot', 'Cut Shot', 'Cut Shot', 'Cut Shot', 'Cut Shot',
#        'Cut Shot', 'Cut Shot', 'Cut Shot', 'Cut Shot', 'Cut Shot',
#        'Cut Shot', 'Cut Shot', 'Cut Shot', 'Cut Shot', 'Cut Shot',
#        'Straight Drive', 'Cut Shot', 'Cut Shot', 'Cut Shot', 'Cut Shot',
#        'Cut Shot', 'Cut Shot', 'Cut Shot', 'Cut Shot', 'Cut Shot',
#        'Straight Drive', 'Straight Drive', 'Cut Shot', 'Cut Shot',
#        'Cut Shot', 'Cut Shot', 'Cut Shot', 'Cut Shot', 'Cut Shot',
#        'Cut Shot', 'Cut Shot', 'Cut Shot', 'Cut Shot', 'Cut Shot',
#        'Cut Shot', 'Cut Shot', 'Cut Shot', 'Straight Drive',
#        'Straight Drive', 'Cut Shot', 'Cut Shot', 'Cut Shot',
#        'Straight Drive', 'Cut Shot', 'Straight Drive', 'Straight Drive',
#        'Straight Drive', 'Cut Shot', 'Cut Shot', 'Cut Shot', 'Cut Shot',
#        'Cut Shot', 'Cut Shot', 'Cut Shot', 'Cut Shot', 'Cut Shot',
#        'Cut Shot', 'Cut Shot', 'Cut Shot', 'Cut Shot', 'Cut Shot',
#        'Cut Shot', 'Cut Shot'], dtype='<U14')

# %%
from sklearn.metrics import accuracy_score # Accuracy metrics 
import pickle 
for algo, model in fit_models.items():
    yhat = model.predict(X_test)
    print(algo, accuracy_score(y_test, yhat))
# Out:
# lr 0.9127906976744186
# rc 0.8992248062015504
# rf 0.9941860465116279
# gb 0.9903100775193798

# %%
fit_models['rf'].predict(X_test)
# Out:
# array(['Sweep Shot', 'Cut Shot', 'Sweep Shot', 'Sweep Shot', 'Cut Shot',
#        'Lofted Shot', 'Cut Shot', 'Cut Shot', 'Sweep Shot', 'Lofted Shot',
#        'Lofted Shot', 'Sweep Shot', 'Cut Shot', 'Sweep Shot', 'Cut Shot',
#        'Lofted Shot', 'Cut Shot', 'Lofted Shot', 'Sweep Shot',
#        'Lofted Shot', 'Sweep Shot', 'Lofted Shot', 'Sweep Shot',
#        'Sweep Shot', 'Lofted Shot', 'Sweep Shot', 'Lofted Shot',
#        'Lofted Shot', 'Lofted Shot', 'Sweep Shot', 'Lofted Shot',
#        'Lofted Shot', 'Lofted Shot', 'Cut Shot', 'Cut Shot', 'Cut Shot',
#        'Cut Shot', 'Sweep Shot', 'Cut Shot', 'Sweep Shot', 'Cut Shot',
#        'Cut Shot', 'Lofted Shot', 'Cut Shot', 'Cut Shot', 'Sweep Shot',
#        'Cut Shot', 'Sweep Shot', 'Cut Shot', 'Lofted Shot', 'Lofted Shot',
#        'Cut Shot', 'Cut Shot', 'Sweep Shot', 'Lofted Shot', 'Sweep Shot',
#        'Sweep Shot', 'Lofted Shot', 'Lofted Shot', 'Lofted Shot',
#        'Cut Shot', 'Sweep Shot', 'Lofted Shot', 'Sweep Shot',
#        'Lofted Shot', 'Cut Shot', 'Lofted Shot', 'Lofted Shot',
#        'Sweep Shot', 'Sweep Shot', 'Cut Shot', 'Sweep Shot',
#        'Lofted Shot', 'Lofted Shot', 'Sweep Shot', 'Cut Shot',
#        'Lofted Shot', 'Cut Shot', 'Sweep Shot', 'Sweep Shot',
#        'Lofted Shot', 'Sweep Shot', 'Sweep Shot', 'Cut Shot', 'Cut Shot',
#        'Sweep Shot', 'Cut Shot', 'Lofted Shot', 'Cut Shot', 'Sweep Shot',
#        'Sweep Shot', 'Sweep Shot', 'Cut Shot', 'Lofted Shot', 'Cut Shot',
#        'Lofted Shot', 'Sweep Shot', 'Cut Shot', 'Cut Shot', 'Cut Shot',
#        'Sweep Shot', 'Cut Shot', 'Sweep Shot', 'Lofted Shot', 'Cut Shot',
#        'Lofted Shot', 'Lofted Shot', 'Sweep Shot', 'Sweep Shot',
#        'Sweep Shot', 'Sweep Shot', 'Cut Shot', 'Lofted Shot', 'Cut Shot',
#        'Cut Shot', 'Lofted Shot', 'Cut Shot', 'Lofted Shot',
#        'Lofted Shot', 'Cut Shot', 'Cut Shot', 'Cut Shot', 'Cut Shot',
#        'Lofted Shot', 'Sweep Shot', 'Cut Shot', 'Cut Shot', 'Sweep Shot',
#        'Cut Shot', 'Cut Shot', 'Sweep Shot', 'Cut Shot', 'Sweep Shot',
#        'Sweep Shot', 'Sweep Shot', 'Sweep Shot', 'Lofted Shot',
#        'Lofted Shot', 'Cut Shot', 'Cut Shot', 'Lofted Shot', 'Cut Shot',
#        'Cut Shot', 'Cut Shot', 'Cut Shot', 'Sweep Shot', 'Cut Shot',
#        'Lofted Shot', 'Cut Shot', 'Sweep Shot', 'Lofted Shot', 'Cut Shot',
#        'Lofted Shot', 'Sweep Shot', 'Cut Shot', 'Sweep Shot', 'Cut Shot',
#        'Sweep Shot', 'Lofted Shot', 'Sweep Shot', 'Lofted Shot',
#        'Cut Shot', 'Lofted Shot', 'Cut Shot', 'Lofted Shot', 'Cut Shot',
#        'Lofted Shot', 'Lofted Shot', 'Sweep Shot', 'Sweep Shot',
#        'Lofted Shot', 'Lofted Shot', 'Sweep Shot', 'Sweep Shot',
#        'Sweep Shot', 'Cut Shot', 'Sweep Shot', 'Cut Shot', 'Sweep Shot',
#        'Cut Shot', 'Cut Shot', 'Lofted Shot', 'Sweep Shot', 'Cut Shot',
#        'Cut Shot', 'Cut Shot', 'Lofted Shot', 'Cut Shot', 'Cut Shot',
#        'Sweep Shot', 'Cut Shot', 'Lofted Shot', 'Sweep Shot',
#        'Lofted Shot', 'Cut Shot', 'Cut Shot', 'Lofted Shot', 'Sweep Shot',
#        'Lofted Shot', 'Lofted Shot', 'Cut Shot', 'Lofted Shot',
#        'Sweep Shot', 'Sweep Shot', 'Lofted Shot', 'Cut Shot', 'Cut Shot',
#        'Cut Shot', 'Sweep Shot', 'Lofted Shot', 'Sweep Shot',
#        'Lofted Shot', 'Lofted Shot', 'Lofted Shot', 'Sweep Shot',
#        'Lofted Shot', 'Sweep Shot', 'Cut Shot', 'Cut Shot', 'Sweep Shot',
#        'Cut Shot', 'Sweep Shot', 'Lofted Shot', 'Cut Shot', 'Cut Shot',
#        'Sweep Shot', 'Cut Shot', 'Cut Shot', 'Lofted Shot', 'Cut Shot',
#        'Sweep Shot', 'Cut Shot', 'Cut Shot', 'Lofted Shot', 'Lofted Shot',
#        'Sweep Shot', 'Sweep Shot', 'Lofted Shot', 'Cut Shot', 'Cut Shot',
#        'Lofted Shot', 'Lofted Shot', 'Lofted Shot', 'Lofted Shot',
#        'Sweep Shot', 'Cut Shot', 'Sweep Shot', 'Lofted Shot',
#        'Sweep Shot', 'Lofted Shot', 'Lofted Shot', 'Sweep Shot',
#        'Cut Shot', 'Cut Shot', 'Cut Shot', 'Sweep Shot', 'Sweep Shot',
#        'Sweep Shot', 'Lofted Shot', 'Lofted Shot', 'Lofted Shot',
#        'Sweep Shot', 'Lofted Shot', 'Cut Shot', 'Cut Shot', 'Lofted Shot',
#        'Lofted Shot', 'Sweep Shot', 'Cut Shot', 'Sweep Shot',
#        'Lofted Shot', 'Lofted Shot', 'Cut Shot', 'Lofted Shot',
#        'Sweep Shot', 'Cut Shot', 'Sweep Shot', 'Cut Shot', 'Lofted Shot',
#        'Cut Shot', 'Sweep Shot', 'Cut Shot', 'Cut Shot', 'Cut Shot',
#        'Cut Shot', 'Sweep Shot', 'Cut Shot', 'Lofted Shot', 'Sweep Shot',
#        'Sweep Shot', 'Lofted Shot', 'Lofted Shot', 'Lofted Shot',
#        'Lofted Shot', 'Sweep Shot', 'Lofted Shot', 'Sweep Shot',
#        'Sweep Shot', 'Cut Shot', 'Lofted Shot', 'Cut Shot', 'Lofted Shot',
#        'Cut Shot', 'Sweep Shot', 'Cut Shot', 'Lofted Shot', 'Lofted Shot',
#        'Lofted Shot', 'Lofted Shot', 'Sweep Shot', 'Sweep Shot',
#        'Sweep Shot', 'Cut Shot', 'Cut Shot', 'Sweep Shot', 'Sweep Shot',
#        'Sweep Shot', 'Lofted Shot', 'Cut Shot', 'Cut Shot', 'Cut Shot',
#        'Cut Shot', 'Cut Shot', 'Sweep Shot', 'Lofted Shot', 'Cut Shot',
#        'Cut Shot', 'Sweep Shot', 'Cut Shot', 'Cut Shot', 'Cut Shot',
#        'Lofted Shot', 'Lofted Shot', 'Sweep Shot', 'Lofted Shot',
#        'Cut Shot', 'Lofted Shot', 'Cut Shot', 'Sweep Shot', 'Cut Shot',
#        'Cut Shot', 'Sweep Shot', 'Lofted Shot', 'Sweep Shot',
#        'Lofted Shot', 'Sweep Shot', 'Lofted Shot', 'Lofted Shot',
#        'Cut Shot', 'Cut Shot', 'Sweep Shot', 'Cut Shot', 'Cut Shot',
#        'Cut Shot', 'Cut Shot', 'Lofted Shot', 'Sweep Shot', 'Lofted Shot',
#        'Cut Shot', 'Cut Shot', 'Sweep Shot', 'Cut Shot', 'Lofted Shot',
#        'Lofted Shot', 'Cut Shot', 'Lofted Shot', 'Lofted Shot',
#        'Lofted Shot', 'Sweep Shot', 'Lofted Shot', 'Cut Shot',
#        'Lofted Shot', 'Lofted Shot', 'Cut Shot', 'Lofted Shot',
#        'Sweep Shot', 'Lofted Shot', 'Lofted Shot', 'Sweep Shot',
#        'Sweep Shot', 'Lofted Shot', 'Cut Shot', 'Lofted Shot',
#        'Lofted Shot', 'Cut Shot', 'Sweep Shot', 'Cut Shot', 'Cut Shot',
#        'Cut Shot', 'Lofted Shot', 'Cut Shot', 'Cut Shot', 'Lofted Shot',
#        'Lofted Shot', 'Cut Shot', 'Sweep Shot', 'Cut Shot', 'Lofted Shot',
#        'Sweep Shot', 'Lofted Shot', 'Lofted Shot', 'Sweep Shot',
#        'Cut Shot', 'Sweep Shot', 'Cut Shot', 'Lofted Shot', 'Lofted Shot',
#        'Lofted Shot', 'Lofted Shot', 'Lofted Shot', 'Cut Shot',
#        'Sweep Shot', 'Cut Shot', 'Sweep Shot', 'Sweep Shot',
#        'Lofted Shot', 'Cut Shot', 'Sweep Shot', 'Cut Shot', 'Lofted Shot',
#        'Sweep Shot', 'Sweep Shot', 'Lofted Shot', 'Lofted Shot',
#        'Lofted Shot', 'Cut Shot', 'Cut Shot', 'Cut Shot', 'Lofted Shot',
#        'Cut Shot', 'Sweep Shot', 'Sweep Shot', 'Lofted Shot',
#        'Lofted Shot', 'Sweep Shot', 'Cut Shot', 'Sweep Shot',
#        'Sweep Shot', 'Sweep Shot', 'Cut Shot', 'Sweep Shot',
#        'Lofted Shot', 'Lofted Shot', 'Lofted Shot', 'Lofted Shot',
#        'Lofted Shot', 'Cut Shot', 'Cut Shot', 'Sweep Shot', 'Cut Shot',
#        'Cut Shot', 'Sweep Shot', 'Sweep Shot', 'Lofted Shot',
#        'Lofted Shot', 'Cut Shot', 'Lofted Shot', 'Sweep Shot', 'Cut Shot',
#        'Cut Shot', 'Cut Shot', 'Sweep Shot', 'Cut Shot', 'Sweep Shot',
#        'Sweep Shot', 'Sweep Shot', 'Cut Shot', 'Lofted Shot',
#        'Sweep Shot', 'Cut Shot', 'Sweep Shot', 'Lofted Shot',
#        'Sweep Shot', 'Lofted Shot', 'Sweep Shot', 'Lofted Shot',
#        'Cut Shot', 'Lofted Shot', 'Cut Shot', 'Lofted Shot', 'Cut Shot',
#        'Cut Shot', 'Cut Shot', 'Cut Shot', 'Sweep Shot', 'Lofted Shot',
#        'Sweep Shot', 'Cut Shot', 'Cut Shot', 'Cut Shot', 'Sweep Shot',
#        'Sweep Shot', 'Sweep Shot', 'Cut Shot', 'Lofted Shot', 'Cut Shot',
#        'Cut Shot', 'Lofted Shot', 'Sweep Shot', 'Lofted Shot',
#        'Sweep Shot', 'Lofted Shot', 'Cut Shot', 'Lofted Shot', 'Cut Shot',
#        'Lofted Shot', 'Sweep Shot', 'Lofted Shot', 'Lofted Shot',
#        'Sweep Shot', 'Cut Shot', 'Sweep Shot', 'Lofted Shot',
#        'Sweep Shot', 'Cut Shot', 'Cut Shot'], dtype=object)

# %%
y_test
# Out:
# 48     Straight Drive
# 99     Straight Drive
# 66     Straight Drive
# 89     Straight Drive
# 84     Straight Drive
# 88     Straight Drive
# 27         Cover Shot
# 68     Straight Drive
# 72     Straight Drive
# 51     Straight Drive
# 22         Cover Shot
# 8          Cover Shot
# 6          Cover Shot
# 32     Straight Drive
# 102    Straight Drive
# 94     Straight Drive
# 106    Straight Drive
# 29     Straight Drive
# 78     Straight Drive
# 117    Straight Drive
# 77     Straight Drive
# 57     Straight Drive
# 42     Straight Drive
# 1          Cover Shot
# 85     Straight Drive
# 55     Straight Drive
# 9          Cover Shot
# 109    Straight Drive
# 35     Straight Drive
# 61     Straight Drive
# 40     Straight Drive
# 62     Straight Drive
# 17         Cover Shot
# 120    Straight Drive
# 59     Straight Drive
# 21         Cover Shot
# 33     Straight Drive
# 107    Straight Drive
# Name: class, dtype: object

# %%
with open('cric_shots.pkl', 'wb') as f:
    pickle.dump(fit_models['rf'], f)

# %%
with open('cric_shots.pkl', 'rb') as f:
    model = pickle.load(f)

# %%
model
# Out:
# Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('randomforestclassifier', RandomForestClassifier())])

# %%
import mediapipe as mp # Import mediapipe
import cv2 # Import opencv
mp_drawing = mp.solutions.drawing_utils # Drawing helpers
mp_holistic = mp.solutions.holistic # Mediapipe Solutions
cap = cv2.VideoCapture("D:\\Users\\91994\\Desktop\\Engineering\\PES 3rd Year\\Capstone Project\\Capstone Project\\videos\\Pepsi IPL 2015- RCB win thriller against SRH.mp4")
# Initiate holistic model
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    
    while cap.isOpened():
        ret, frame = cap.read()
        
        # Recolor Feed
        try:
            image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
            image1=cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        except:
            break
        image.flags.writeable = False        
        
        # Make Detections
        results = holistic.process(image)
        # print(results.face_landmarks)
        
        # face_landmarks, pose_landmarks, left_hand_landmarks, right_hand_landmarks
        
        # Recolor image back to BGR for rendering
        image.flags.writeable = True   
        image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
        #image=cv2.flip(image,1)
        
        
        
        
        # 1. Draw face landmarks
        mp_drawing.draw_landmarks(image, results.face_landmarks, mp_holistic.FACEMESH_TESSELATION, 
                                 mp_drawing.DrawingSpec(color=(80,110,10), thickness=1, circle_radius=1),
                                 mp_drawing.DrawingSpec(color=(80,256,121), thickness=1, circle_radius=1)
                                 )
        
        # 2. Right hand
        mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                                 mp_drawing.DrawingSpec(color=(80,22,10), thickness=2, circle_radius=4),
                                 mp_drawing.DrawingSpec(color=(80,44,121), thickness=2, circle_radius=2)
                                 )

        # 3. Left Hand
        mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                                 mp_drawing.DrawingSpec(color=(121,22,76), thickness=2, circle_radius=4),
                                 mp_drawing.DrawingSpec(color=(121,44,250), thickness=2, circle_radius=2)
                                 )

        # 4. Pose Detections
        mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS, 
                                 mp_drawing.DrawingSpec(color=(245,117,66), thickness=2, circle_radius=4),
                                 mp_drawing.DrawingSpec(color=(245,66,230), thickness=2, circle_radius=2)
                                 )
        # Export coordinates
        try:
            # Extract Pose landmarks
    
            pose = results.pose_landmarks.landmark
            pose_row = list(np.array([[landmark.x, landmark.y, landmark.z, landmark.visibility] for landmark in pose]).flatten())
            
            # Extract Face landmarks
            '''face = results.face_landmarks.landmark
            face_row = list(np.array([[landmark.x, landmark.y, landmark.z, landmark.visibility] for landmark in face]).flatten())'''
            
            # Concate rows
            row = pose_row
            
            
#             # Append class name 
#             row.insert(0, class_name)
            
#             # Export to CSV
#             with open('coords.csv', mode='a', newline='') as f:
#                 csv_writer = csv.writer(f, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)
#                 csv_writer.writerow(row) 

            # Make Detections
            X = pd.DataFrame([row])
            body_language_class = model.predict(X)[0]
            body_language_prob = model.predict_proba(X)[0]
            print(body_language_class,body_language_prob)
    
            
            # Grab ear coords
            coords = tuple(np.multiply(
                            np.array(
                                (results.pose_landmarks.landmark[mp_holistic.PoseLandmark.LEFT_EAR].x, 
                                 results.pose_landmarks.landmark[mp_holistic.PoseLandmark.LEFT_EAR].y))
                        , [640,480]).astype(int))
            
            cv2.rectangle(image, 
                          (coords[0], coords[1]+5), 
                          (coords[0]+len(body_language_class)*20, coords[1]-30), 
                          (245, 117, 16), -1)
            cv2.putText(image, body_language_class, coords, 
                        cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)
            
            # Get status box
            cv2.rectangle(image, (0,0), (250, 60), (245, 117, 16), -1)
            
            # Display Class
            cv2.putText(image, 'CLASS'
                        , (95,12), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 0), 1, cv2.LINE_AA)
            cv2.putText(image, body_language_class.split(' ')[0]
                        , (90,40), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)
            
            # Display Probability
            cv2.putText(image, 'PROB'
                        , (15,12), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 0), 1, cv2.LINE_AA)
            cv2.putText(image, str(round(body_language_prob[np.argmax(body_language_prob)],2))
                        , (10,40), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)
        except:
            pass
                        
        cv2.imshow('Raw Webcam Feed', image)

        if cv2.waitKey(10) & 0xFF == ord('q'):
            break

cap.release()
cv2.destroyAllWindows()
# Out:
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Lofted Shot [0.29 0.51 0.2 ]
# Lofted Shot [0.24 0.46 0.3 ]
# Sweep Shot [0.2  0.29 0.51]
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Sweep Shot [0.16 0.15 0.69]
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Sweep Shot [0.35 0.18 0.47]
# Sweep Shot [0.35 0.14 0.51]
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Lofted Shot [0.13 0.63 0.24]
# Lofted Shot [0.11 0.77 0.12]
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Sweep Shot [0.23 0.37 0.4 ]
# Lofted Shot [0.26 0.4  0.34]
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Sweep Shot [0.2  0.29 0.51]
# Sweep Shot [0.26 0.32 0.42]
# Sweep Shot [0.24 0.29 0.47]
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Sweep Shot [0.19 0.3  0.51]
# Sweep Shot [0.23 0.32 0.45]
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Sweep Shot [0.18 0.23 0.59]
# Sweep Shot [0.15 0.3  0.55]
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Sweep Shot [0.24 0.23 0.53]
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Sweep Shot [0.2  0.16 0.64]
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Sweep Shot [0.26 0.16 0.58]
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Cut Shot [0.57 0.27 0.16]
# Cut Shot [0.52 0.29 0.19]
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Cut Shot [0.54 0.26 0.2 ]
# Cut Shot [0.54 0.25 0.21]
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Cut Shot [0.46 0.3  0.24]
# Cut Shot [0.5  0.26 0.24]
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Cut Shot [0.41 0.31 0.28]
# Cut Shot [0.39 0.33 0.28]
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Cut Shot [0.38 0.34 0.28]
# Cut Shot [0.38 0.35 0.27]
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Cut Shot [0.43 0.28 0.29]
# Cut Shot [0.42 0.31 0.27]
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Cut Shot [0.41 0.3  0.29]
# Cut Shot [0.46 0.2  0.34]
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Cut Shot [0.49 0.18 0.33]
# Cut Shot [0.51 0.16 0.33]
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Cut Shot [0.49 0.17 0.34]
# Cut Shot [0.48 0.16 0.36]
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Cut Shot [0.49 0.15 0.36]
# Cut Shot [0.46 0.16 0.38]
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Cut Shot [0.5  0.17 0.33]
# Cut Shot [0.5  0.18 0.32]
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Cut Shot [0.49 0.15 0.36]
# Cut Shot [0.47 0.17 0.36]
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Cut Shot [0.47 0.17 0.36]
# Cut Shot [0.49 0.17 0.34]
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Cut Shot [0.48 0.17 0.35]
# Cut Shot [0.47 0.18 0.35]
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Cut Shot [0.48 0.18 0.34]
# Cut Shot [0.47 0.18 0.35]
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Cut Shot [0.49 0.16 0.35]
# Cut Shot [0.48 0.16 0.36]
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Cut Shot [0.43 0.19 0.38]
# Cut Shot [0.43 0.21 0.36]
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Cut Shot [0.42 0.25 0.33]
# Cut Shot [0.43 0.25 0.32]
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Cut Shot [0.41 0.25 0.34]
# Cut Shot [0.39 0.27 0.34]
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Cut Shot [0.39 0.28 0.33]
# Cut Shot [0.38 0.29 0.33]
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Cut Shot [0.4  0.26 0.34]
# Cut Shot [0.39 0.24 0.37]
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Cut Shot [0.42 0.23 0.35]
# Sweep Shot [0.37 0.23 0.4 ]
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Sweep Shot [0.38 0.22 0.4 ]
# Sweep Shot [0.37 0.18 0.45]
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Sweep Shot [0.39 0.15 0.46]
# Sweep Shot [0.37 0.15 0.48]
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Sweep Shot [0.36 0.15 0.49]
# Sweep Shot [0.37 0.15 0.48]
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Sweep Shot [0.39 0.16 0.45]
# Sweep Shot [0.35 0.16 0.49]
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Sweep Shot [0.38 0.16 0.46]
# Sweep Shot [0.38 0.15 0.47]
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Sweep Shot [0.34 0.18 0.48]
# Sweep Shot [0.35 0.19 0.46]
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Sweep Shot [0.33 0.17 0.5 ]
# Sweep Shot [0.34 0.15 0.51]
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Sweep Shot [0.35 0.15 0.5 ]
# Sweep Shot [0.33 0.14 0.53]
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Sweep Shot [0.33 0.14 0.53]
# Sweep Shot [0.31 0.14 0.55]
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Sweep Shot [0.31 0.14 0.55]
# Sweep Shot [0.32 0.12 0.56]
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Sweep Shot [0.33 0.12 0.55]
# Sweep Shot [0.31 0.13 0.56]
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Sweep Shot [0.31 0.13 0.56]
# Sweep Shot [0.31 0.13 0.56]
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Sweep Shot [0.32 0.13 0.55]
# Sweep Shot [0.32 0.14 0.54]
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Sweep Shot [0.32 0.14 0.54]
# Sweep Shot [0.31 0.13 0.56]
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Sweep Shot [0.31 0.11 0.58]
# Sweep Shot [0.31 0.13 0.56]
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Sweep Shot [0.32 0.13 0.55]
# Sweep Shot [0.32 0.16 0.52]
# Sweep Shot [0.32 0.15 0.53]
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Sweep Shot [0.33 0.14 0.53]
# Sweep Shot [0.32 0.19 0.49]
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Sweep Shot [0.32 0.18 0.5 ]
# Sweep Shot [0.34 0.12 0.54]
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Sweep Shot [0.35 0.1  0.55]
# Sweep Shot [0.35 0.13 0.52]
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Sweep Shot [0.33 0.11 0.56]
# Sweep Shot [0.34 0.12 0.54]
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
# ...
#   warnings.warn(
# Sweep Shot [0.12 0.3  0.58]
# Sweep Shot [0.13 0.12 0.75]
# Sweep Shot [0.11 0.15 0.74]
# Sweep Shot [0.17 0.11 0.72]
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Sweep Shot [0.19 0.11 0.7 ]
# Sweep Shot [0.2  0.09 0.71]
# Sweep Shot [0.28 0.15 0.57]
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Sweep Shot [0.22 0.2  0.58]
# Sweep Shot [0.19 0.25 0.56]
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Sweep Shot [0.23 0.25 0.52]
# Sweep Shot [0.22 0.24 0.54]
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Sweep Shot [0.19 0.33 0.48]
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Sweep Shot [0.25 0.14 0.61]
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Sweep Shot [0.21 0.23 0.56]
# Sweep Shot [0.28 0.23 0.49]
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Sweep Shot [0.19 0.23 0.58]
# Sweep Shot [0.23 0.23 0.54]
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Sweep Shot [0.22 0.26 0.52]
# Sweep Shot [0.23 0.24 0.53]
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Cut Shot [0.38 0.24 0.38]
# Sweep Shot [0.33 0.29 0.38]
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Cut Shot [0.36 0.3  0.34]
# Sweep Shot [0.24 0.33 0.43]
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Sweep Shot [0.31 0.33 0.36]
# Sweep Shot [0.25 0.32 0.43]
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Sweep Shot [0.3  0.28 0.42]
# Sweep Shot [0.26 0.31 0.43]
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Sweep Shot [0.31 0.29 0.4 ]
# Sweep Shot [0.32 0.28 0.4 ]
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Sweep Shot [0.35 0.26 0.39]
# Sweep Shot [0.32 0.26 0.42]
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Sweep Shot [0.34 0.28 0.38]
# Sweep Shot [0.32 0.3  0.38]
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Sweep Shot [0.32 0.29 0.39]
# Sweep Shot [0.28 0.2  0.52]
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Lohith\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Sweep Shot [0.32 0.22 0.46]
# Sweep Shot [0.32 0.25 0.43]
# Sweep Shot [0.31 0.29 0.4 ]
